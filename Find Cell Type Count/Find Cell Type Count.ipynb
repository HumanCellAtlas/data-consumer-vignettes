# %% [markdown]
# # Find the Number of Cells of a Specific Cell Type
#
# I need to find how many cells of a certain organ type are available in the HCA database. How can I go about doing this?
#
# First, let's get set up.

# %%
raise Exception("Raising an exception to see if tests fail too")

# %%
import hca.dss
client = hca.dss.DSSClient()

# %% [markdown]
# Now, what type of cells are we looking for? Maybe cells from a _hematopoietic system_?

# %%
organ_type = 'hematopoietic system'

# %% [markdown]
# To find what cells appear in the database, we'll need to do some _searching_: specifically, using the __post_search()__ method. `post_search()` has four parameters: `es_query`, `output_format`, `replica`, and `per_page`, two of which are optional: `output_format` and `per_page`.
#
# Let's not worry about `per_page`; we won't be needing it for this. For `replica`, we'll be using AWS, and for `output_format`, we'll want to use the mode `raw`. Using `raw` will return get the verbatim JSON metadata for bundles that match our query, which we'll need in order to view details on the organ type.
#
# Assuming we don't know how to find the fields for our ElasticSearch query, we'll start by looking for them first. Our query should find all bundles that have both an _organ type_ of hematopoietic system and _at least one cell_ in the sample. In the end, it should look something like this:
#
# ```json
# query = {
#     "query" : {
#         "bool" : {
#             "must" : [{
#                 "match" : {
#                     "some.path.to.the.organ.type" : organ_type
#                 }
#             }, {
#                 "range" : {
#                     "some.path.to.the.total.number.of.cells" : {
#                         "gt" : 0
#                     }
#                 }
#             }]
#         }
#     }
# }
# ```
#
# To find these fields, we can examine a bundle -- _any_ bundle containing what we need -- in its `raw` form. Let's do a search over everything to find one.

# %%
client.post_search(es_query={}, replica='aws', output_format='raw')['results'][0]
# Out:
# {'bundle_fqid': '0fd98881-8879-4928-939d-e3583ae0d006.2018-05-01T070337.608744Z',
#  'bundle_url': 'https://dss.data.humancellatlas.org/v1/bundles/0fd98881-8879-4928-939d-e3583ae0d006?version=2018-05-01T070337.608744Z&replica=aws',
#  'metadata': {'files': {},
#   'manifest': {'creator_uid': 0,
#    'files': [{'content-type': 'application/json',
#      'crc32c': '003ad03e',
#      'indexed': True,
#      'name': 'cell.json',
#      's3-etag': 'fb5aac9f8f0a9da710998cac814a33dc',
#      'sha1': '6e1de4809aa92d3e142830fbcf353c2e03556335',
#      'sha256': 'cb718e73527242a757431cbbc94b40878e201608064b77ca6b9ebf900c3c9ee6',
#      'size': 42,
#      'uuid': 'ff17b618-e94e-4c0a-a41a-f339ce917358',
#      'version': '2018-05-01T070332.393227Z'},
#     {'content-type': 'gzip',
#      'crc32c': '942cd9d6',
#      'indexed': False,
#      'name': 'SRR2967608_2.fastq.gz',
#      's3-etag': 'fb9bbafee8a92ced414b3658b1bb9517',
#      'sha1': 'bb5c8a68c155bad257cb7b93faef71a116cecba2',
#      'sha256': 'c0d11199740a66150b8bb70a0474d8de9819e77f3f77b55dd04790e3fe6fb53c',
#      'size': 23675941,
#      'uuid': '0c275b5e-edb3-4aeb-882b-1955aa38f507',
#      'version': '2018-05-01T070333.321613Z'},
#     {'content-type': 'application/json',
#      'crc32c': '4db24aeb',
#      'indexed': True,
#      'name': 'project.json',
#      's3-etag': 'f2a84e3cc346735eb43cb50010ba583a',
#      'sha1': '99d9ab9b83d900b23af4916677130e54197f9082',
#      'sha256': '90cdd049c9654e5048a73c3f9ce575d805b72f6c66e6dbacfc3789a7d0b29e4e',
#      'size': 3450,
#      'uuid': 'f0d0c169-54e7-4879-a7e3-ff82cfeb2989',
#      'version': '2018-05-01T070334.176185Z'},
#     {'content-type': 'gzip',
#      'crc32c': 'e978e85d',
#      'indexed': False,
#      'name': 'SRR2967608_1.fastq.gz',
#      's3-etag': '89f6f8bec37ec1fc4560f3f99d47721d',
#      'sha1': '58f03f7c6c0887baa54da85db5c820cfbe25d367',
#      'sha256': '9b4c0dde8683f924975d0867903dc7a967f46bee5c0a025c451b9ba73e43f120',
#      'size': 22220717,
#      'uuid': 'f20e0e69-9f5b-4867-bd73-ff1607a4aac8',
#      'version': '2018-05-01T070335.043125Z'},
#     {'content-type': 'application/json',
#      'crc32c': 'ed0f785d',
#      'indexed': True,
#      'name': 'sample.json',
#      's3-etag': 'ecbaee942c4c617d764f971ab8e6b85c',
#      'sha1': '1e2068289735e8b30e75822b6a66660ffdfc57a4',
#      'sha256': '38641578ab2343c31dbb56b114f6e4060862c01fde2f84395d3b99f64423afd9',
#      'size': 3060,
#      'uuid': '184ce7ce-92ba-4d61-a0f5-4a7b86501ebe',
#      'version': '2018-05-01T070335.634252Z'},
#     {'content-type': 'application/json',
#      'crc32c': 'e5466084',
#      'indexed': True,
#      'name': 'manifest.json',
#      's3-etag': 'd8674c819d58168b36e7c197d07b0247',
#      'sha1': 'c897279ca670469ab4044071396301a3d1e6512f',
#      'sha256': '2652667a03099e12af8582e7bfe3d83169cb98b8ee784cf713dd00fa1fe479b1',
#      'size': 303,
#      'uuid': '29780120-9edd-4761-b79d-c15a04f90ec9',
#      'version': '2018-05-01T070336.418230Z'},
#     {'content-type': 'application/json',
#      'crc32c': 'd31000c8',
#      'indexed': True,
#      'name': 'assay.json',
#      's3-etag': '7b794fa0ecd2d9d05316291c8b9ff818',
#      'sha1': 'f9ec5bec08d09a7c0a4aff8eeb08cfcdda55192b',
#      'sha256': '90648706a325a059966f026783a2a4494dcaaf304182df7bff424fb051d8e378',
#      'size': 655,
#      'uuid': '02161446-522e-4afd-8331-6d3727c8e5a4',
#      'version': '2018-05-01T070336.974752Z'}],
#    'format': '0.0.1',
#    'version': '2018-05-01T070337.608744Z'},
#   'state': 'new',
#   'uuid': '0fd98881-8879-4928-939d-e3583ae0d006'},
#  'search_score': 1.0}

# %% [markdown]
# Well, that's not very helpful. The `files` section is empty. Let's try another one.

# %%
client.post_search(es_query={}, replica='aws', output_format='raw')['results'][20]
# Out:
# {'bundle_fqid': '1e352213-af04-4678-b659-f245e924a888.2018-03-29T141756.401707Z',
#  'bundle_url': 'https://dss.data.humancellatlas.org/v1/bundles/1e352213-af04-4678-b659-f245e924a888?version=2018-03-29T141756.401707Z&replica=aws',
#  'metadata': {'files': {'biomaterial_json': {'biomaterials': [{'content': {'biomaterial_core': {'biomaterial_id': '22011_1#68',
#         'has_input_biomaterial': '1134_T',
#         'ncbi_taxon_id': [10090]},
#        'describedBy': 'https://schema.humancellatlas.org/type/biomaterial/5.1.0/cell_suspension',
#        'genus_species': [{'ontology': 'NCBITaxon:10090',
#          'text': 'Mus musculus'}],
#        'schema_type': 'biomaterial',
#        'target_cell_type': [{'ontology': 'CL:0000625', 'text': 'CD8+ T cell'}],
#        'total_estimated_cells': 1},
#       'hca_ingest': {'accession': '',
#        'document_id': 'd7c77c44-7ded-4e26-9046-f851a2e5ee37',
#        'submissionDate': '2018-03-28T14:00:02.182Z',
#        'updateDate': '2018-03-28T14:48:30.990Z'}},
#      {'content': {'biomaterial_core': {'biomaterial_id': '1134_T',
#         'biomaterial_name': 'Mouse_day11_T_rep1',
#         'has_input_biomaterial': '1134',
#         'ncbi_taxon_id': [10090],
#         'supplementary_files': ['FACS_sorting_markers.pdf']},
#        'describedBy': 'https://schema.humancellatlas.org/type/biomaterial/5.1.0/specimen_from_organism',
#        'genus_species': [{'ontology': 'NCBITaxon:10090',
#          'text': 'Mus musculus'}],
#        'organ': {'text': 'tumor'},
#        'schema_type': 'biomaterial'},
#       'hca_ingest': {'accession': '',
#        'document_id': '6a184eda-f065-4be1-b23f-797a8bb5b3af',
#        'submissionDate': '2018-03-28T13:58:57.117Z',
#        'updateDate': '2018-03-28T14:48:14.773Z'}},
#      {'content': {'biological_sex': 'female',
#        'biomaterial_core': {'biomaterial_id': '1134',
#         'biomaterial_name': 'Mouse_day11_rep1',
#         'ncbi_taxon_id': [10090]},
#        'describedBy': 'https://schema.humancellatlas.org/type/biomaterial/5.1.0/donor_organism',
#        'disease': [{'ontology': 'EFO:0000756',
#          'text': 'subcutaneous melanoma'}],
#        'genus_species': [{'ontology': 'NCBITaxon:10090',
#          'text': 'Mus musculus'}],
#        'is_living': False,
#        'mus_musculus_specific': {'strain': [{'text': 'C57BL/6'}]},
#        'organism_age': '6-12',
#        'organism_age_unit': {'ontology': 'UO:0000034', 'text': 'week'},
#        'schema_type': 'biomaterial'},
#       'hca_ingest': {'accession': '',
#        'document_id': '665b75b4-8638-4a15-83e5-f3928dd29314',
#        'submissionDate': '2018-03-28T13:55:51.172Z',
#        'updateDate': '2018-03-28T14:22:45.353Z'}}],
#     'describedBy': 'https://schema.humancellatlas.org/bundle/5.1.0/biomaterial',
#     'schema_type': 'biomaterial_bundle',
#     'schema_version': '5.1.0'},
#    'file_json': {'describedBy': 'https://schema.humancellatlas.org/bundle/1.0.0/file',
#     'files': [{'content': {'describedBy': 'https://schema.humancellatlas.org/type/file/5.1.0/sequence_file',
#        'file_core': {'file_format': 'fastq.gz',
#         'file_name': '22011_1#68_1.fastq.gz'},
#        'lane_index': 1,
#        'read_index': 'read1',
#        'schema_type': 'file'},
#       'hca_ingest': {'document_id': '7991a95b-3f58-413e-bdb0-9516c7429cd4',
#        'submissionDate': '2018-03-28T14:00:23.882Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/file/5.1.0/sequence_file',
#        'file_core': {'file_format': 'fastq.gz',
#         'file_name': '22011_1#68_2.fastq.gz'},
#        'lane_index': 1,
#        'read_index': 'read2',
#        'schema_type': 'file'},
#       'hca_ingest': {'document_id': 'd1aec1c7-0005-4d51-9b94-84aa7149fd1b',
#        'submissionDate': '2018-03-28T14:00:23.891Z'}}],
#     'schema_type': 'file_bundle',
#     'schema_version': '1.0.0'},
#    'links_json': {'describedBy': 'https://schema.humancellatlas.org/bundle/1.0.0/links',
#     'links': [{'destination_id': 'b7bbb2dc-3131-47c3-bcb9-4b7e0eeed902',
#       'destination_type': 'dissociation_process',
#       'source_id': '6a184eda-f065-4be1-b23f-797a8bb5b3af',
#       'source_type': 'biomaterial'},
#      {'destination_id': 'd7c77c44-7ded-4e26-9046-f851a2e5ee37',
#       'destination_type': 'biomaterial',
#       'source_id': 'b7bbb2dc-3131-47c3-bcb9-4b7e0eeed902',
#       'source_type': 'dissociation_process'},
#      {'destination_id': 'c9a1e203-bddc-45d3-87c4-6010be8e0127',
#       'destination_type': 'protocol',
#       'source_id': 'b7bbb2dc-3131-47c3-bcb9-4b7e0eeed902',
#       'source_type': 'dissociation_process'},
#      {'destination_id': '6a184eda-f065-4be1-b23f-797a8bb5b3af',
#       'destination_type': 'biomaterial',
#       'source_id': '0a066f9d-02e6-4ef6-92cc-59a318f416ba',
#       'source_type': 'process'},
#      {'destination_id': '0a066f9d-02e6-4ef6-92cc-59a318f416ba',
#       'destination_type': 'process',
#       'source_id': '665b75b4-8638-4a15-83e5-f3928dd29314',
#       'source_type': 'biomaterial'},
#      {'destination_id': '87beb50f-521d-4102-9cb0-ca7b6f151afc',
#       'destination_type': 'enrichment_process',
#       'source_id': '6a184eda-f065-4be1-b23f-797a8bb5b3af',
#       'source_type': 'biomaterial'},
#      {'destination_id': 'd7c77c44-7ded-4e26-9046-f851a2e5ee37',
#       'destination_type': 'biomaterial',
#       'source_id': '87beb50f-521d-4102-9cb0-ca7b6f151afc',
#       'source_type': 'enrichment_process'},
#      {'destination_id': 'a1c80daf-58b0-4b7a-8e29-d0130493c8e6',
#       'destination_type': 'protocol',
#       'source_id': '87beb50f-521d-4102-9cb0-ca7b6f151afc',
#       'source_type': 'enrichment_process'},
#      {'destination_id': '6a184eda-f065-4be1-b23f-797a8bb5b3af',
#       'destination_type': 'biomaterial',
#       'source_id': '0a066f9d-02e6-4ef6-92cc-59a318f416ba',
#       'source_type': 'process'},
#      {'destination_id': '0a066f9d-02e6-4ef6-92cc-59a318f416ba',
#       'destination_type': 'process',
#       'source_id': '665b75b4-8638-4a15-83e5-f3928dd29314',
#       'source_type': 'biomaterial'},
#      {'destination_id': '8caf3d2b-7dba-40ca-a2d7-c69b433ba70b',
#       'destination_type': 'enrichment_process',
#       'source_id': '6a184eda-f065-4be1-b23f-797a8bb5b3af',
#       'source_type': 'biomaterial'},
#      {'destination_id': 'd7c77c44-7ded-4e26-9046-f851a2e5ee37',
#       'destination_type': 'biomaterial',
#       'source_id': '8caf3d2b-7dba-40ca-a2d7-c69b433ba70b',
#       'source_type': 'enrichment_process'},
#      {'destination_id': 'a1c80daf-58b0-4b7a-8e29-d0130493c8e6',
#       'destination_type': 'protocol',
#       'source_id': '8caf3d2b-7dba-40ca-a2d7-c69b433ba70b',
#       'source_type': 'enrichment_process'},
#      {'destination_id': '6a184eda-f065-4be1-b23f-797a8bb5b3af',
#       'destination_type': 'biomaterial',
#       'source_id': '0a066f9d-02e6-4ef6-92cc-59a318f416ba',
#       'source_type': 'process'},
#      {'destination_id': '0a066f9d-02e6-4ef6-92cc-59a318f416ba',
#       'destination_type': 'process',
#       'source_id': '665b75b4-8638-4a15-83e5-f3928dd29314',
#       'source_type': 'biomaterial'},
#      {'destination_id': 'c86e1752-6388-459f-a8f3-6d1e20442acb',
#       'destination_type': 'enrichment_process',
#       'source_id': '6a184eda-f065-4be1-b23f-797a8bb5b3af',
#       'source_type': 'biomaterial'},
#      {'destination_id': 'd7c77c44-7ded-4e26-9046-f851a2e5ee37',
#       'destination_type': 'biomaterial',
#       'source_id': 'c86e1752-6388-459f-a8f3-6d1e20442acb',
#       'source_type': 'enrichment_process'},
#      {'destination_id': 'a1c80daf-58b0-4b7a-8e29-d0130493c8e6',
#       'destination_type': 'protocol',
#       'source_id': 'c86e1752-6388-459f-a8f3-6d1e20442acb',
#       'source_type': 'enrichment_process'},
#      {'destination_id': '6a184eda-f065-4be1-b23f-797a8bb5b3af',
#       'destination_type': 'biomaterial',
#       'source_id': '0a066f9d-02e6-4ef6-92cc-59a318f416ba',
#       'source_type': 'process'},
#      {'destination_id': '0a066f9d-02e6-4ef6-92cc-59a318f416ba',
#       'destination_type': 'process',
#       'source_id': '665b75b4-8638-4a15-83e5-f3928dd29314',
#       'source_type': 'biomaterial'},
#      {'destination_id': '687065f3-c70f-46c3-8452-a5eead33a1bf',
#       'destination_type': 'library_preparation_process',
#       'source_id': 'd7c77c44-7ded-4e26-9046-f851a2e5ee37',
#       'source_type': 'biomaterial'},
#      {'destination_id': '7991a95b-3f58-413e-bdb0-9516c7429cd4',
#       'destination_type': 'file',
#       'source_id': '687065f3-c70f-46c3-8452-a5eead33a1bf',
#       'source_type': 'library_preparation_process'},
#      {'destination_id': 'd1aec1c7-0005-4d51-9b94-84aa7149fd1b',
#       'destination_type': 'file',
#       'source_id': '687065f3-c70f-46c3-8452-a5eead33a1bf',
#       'source_type': 'library_preparation_process'},
#      {'destination_id': '52d79a89-4b49-4c1b-b857-5cc5da07f643',
#       'destination_type': 'protocol',
#       'source_id': '687065f3-c70f-46c3-8452-a5eead33a1bf',
#       'source_type': 'library_preparation_process'},
#      {'destination_id': 'e2d2b107-b9c4-48bc-921c-83d40cf75017',
#       'destination_type': 'sequencing_process',
#       'source_id': 'd7c77c44-7ded-4e26-9046-f851a2e5ee37',
#       'source_type': 'biomaterial'},
#      {'destination_id': '7991a95b-3f58-413e-bdb0-9516c7429cd4',
#       'destination_type': 'file',
#       'source_id': 'e2d2b107-b9c4-48bc-921c-83d40cf75017',
#       'source_type': 'sequencing_process'},
#      {'destination_id': 'd1aec1c7-0005-4d51-9b94-84aa7149fd1b',
#       'destination_type': 'file',
#       'source_id': 'e2d2b107-b9c4-48bc-921c-83d40cf75017',
#       'source_type': 'sequencing_process'},
#      {'destination_id': 'ca6096cf-13c1-4930-8308-6ab05865e2c9',
#       'destination_type': 'protocol',
#       'source_id': 'e2d2b107-b9c4-48bc-921c-83d40cf75017',
#       'source_type': 'sequencing_process'}],
#     'schema_type': 'link_bundle',
#     'schema_version': '1.0.0'},
#    'process_json': {'describedBy': 'https://schema.humancellatlas.org/bundle/5.2.1/process',
#     'processes': [{'content': {'describedBy': 'https://schema.humancellatlas.org/type/process/biomaterial_collection/5.1.0/dissociation_process',
#        'dissociation_method': 'mechanical',
#        'nucleic_acid_source': 'single cell',
#        'process_core': {'process_id': 'TissueDissociationProcess',
#         'process_name': 'Extracting cells from lymph nodes'},
#        'schema_type': 'process'},
#       'hca_ingest': {'accession': '',
#        'document_id': 'b7bbb2dc-3131-47c3-bcb9-4b7e0eeed902',
#        'submissionDate': '2018-03-28T14:04:14.574Z',
#        'updateDate': '2018-03-28T14:13:28.361Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/process/1.0.0/process',
#        'process_core': {'process_id': 'sampling_process_37'},
#        'schema_type': 'process'},
#       'hca_ingest': {'accession': '',
#        'document_id': '0a066f9d-02e6-4ef6-92cc-59a318f416ba',
#        'submissionDate': '2018-03-28T14:00:19.513Z',
#        'updateDate': '2018-03-28T14:42:13.090Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/process/biomaterial_collection/5.1.0/enrichment_process',
#        'enrichment_method': 'FACS',
#        'markers': 'CD45+ CD3e+ CD8a+',
#        'process_core': {'process_id': 'FACS1'},
#        'schema_type': 'process'},
#       'hca_ingest': {'accession': '',
#        'document_id': '87beb50f-521d-4102-9cb0-ca7b6f151afc',
#        'submissionDate': '2018-03-28T14:05:22.303Z',
#        'updateDate': '2018-03-28T14:26:50.868Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/process/biomaterial_collection/5.1.0/enrichment_process',
#        'enrichment_method': 'FACS',
#        'markers': 'CD45+ CD3e+ CD4+',
#        'process_core': {'process_id': 'FACS5'},
#        'schema_type': 'process'},
#       'hca_ingest': {'accession': '',
#        'document_id': '8caf3d2b-7dba-40ca-a2d7-c69b433ba70b',
#        'submissionDate': '2018-03-28T14:05:22.316Z',
#        'updateDate': '2018-03-28T14:25:31.688Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/process/biomaterial_collection/5.1.0/enrichment_process',
#        'enrichment_method': 'FACS',
#        'markers': 'CD45+ IL7Ra+',
#        'process_core': {'process_id': 'FACS7.6'},
#        'schema_type': 'process'},
#       'hca_ingest': {'accession': '',
#        'document_id': 'c86e1752-6388-459f-a8f3-6d1e20442acb',
#        'submissionDate': '2018-03-28T14:05:48.281Z',
#        'updateDate': '2018-03-28T14:33:39.418Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/process/sequencing/5.1.0/library_preparation_process',
#        'end_bias': 'full length',
#        'input_nucleic_acid_molecule': {'ontology': 'OBI:0000869',
#         'text': 'polyA RNA'},
#        'library_construction_approach': 'Smart-seq2',
#        'primer': 'poly-dT',
#        'process_core': {'process_id': 'lib_prep_1',
#         'process_name': 'Library preparation process'},
#        'schema_type': 'process',
#        'strand': 'unstranded',
#        'umi_barcode': {'barcode_length': 16,
#         'barcode_offset': 0,
#         'barcode_read': 'Read 1'}},
#       'hca_ingest': {'accession': '',
#        'document_id': '687065f3-c70f-46c3-8452-a5eead33a1bf',
#        'submissionDate': '2018-03-28T14:05:43.803Z',
#        'updateDate': '2018-03-28T14:43:01.679Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/process/sequencing/5.1.0/sequencing_process',
#        'instrument_manufacturer_model': {'ontology': 'EFO:0008567',
#         'text': 'Illumina HiSeq 2500'},
#        'paired_ends': True,
#        'process_core': {'process_id': 'seq_64',
#         'process_name': 'Sequencing process'},
#        'schema_type': 'process',
#        'smartseq2': {'plate_id': '567', 'well_name': 'B10'}},
#       'hca_ingest': {'accession': '',
#        'document_id': 'e2d2b107-b9c4-48bc-921c-83d40cf75017',
#        'submissionDate': '2018-03-28T14:04:31.247Z',
#        'updateDate': '2018-03-28T14:15:39.366Z'}}],
#     'schema_type': 'process_bundle',
#     'schema_version': '5.2.1'},
#    'project_json': {'content': {'contributors': [{'address': 'Wellcome Trust Genome Campus, Cambridge UK',
#        'contact_name': 'Sarah,A,Teichmann',
#        'country': 'UK',
#        'email': 'st9@sanger.ac.uk',
#        'institution': 'Wellcome Trust Sanger Institute',
#        'laboratory': 'Sarah Teichmann'},
#       {'address': 'Wellcome Trust Genome Campus, Cambridge UK',
#        'contact_name': 'Mirjana,,Efremova',
#        'country': 'UK',
#        'email': 'me5@sanger.ac.uk',
#        'institution': 'Wellcome Trust Sanger Institute',
#        'laboratory': 'Sarah Teichmann'},
#       {'address': 'Wellcome Trust Genome Campus, Cambridge UK',
#        'contact_name': 'Bidesh,,Mahata',
#        'country': 'UK',
#        'email': 'bm11@sanger.ac.uk',
#        'institution': 'Wellcome Trust Sanger Institute',
#        'laboratory': 'Sarah Teichmann'},
#       {'address': 'Box 197, Cambridge Biomedical Campus, Cambridge, CB2 0XZ',
#        'contact_name': 'Jacqueline,D,Shields',
#        'country': 'UK',
#        'email': 'JS970@MRCCU.cam.ac.uk',
#        'institution': 'University of Cambridge',
#        'laboratory': 'MRC Cancer Unit'},
#       {'address': 'Box 197, Cambridge Biomedical Campus, Cambridge, CB2 0XZ',
#        'contact_name': 'Sarah,,Davidson',
#        'country': 'UK',
#        'email': 'SED49@MRCCU.cam.ac.uk',
#        'institution': 'University of Cambridge',
#        'laboratory': 'MRC Cancer Unit'},
#       {'contact_name': 'Angela,,Riedel',
#        'country': 'Germany',
#        'email': 'a.riedel@dkfz-heidelberg.de',
#        'institution': 'DKFZ German Cancer Research Center'},
#       {'address': 'Wellcome Trust Genome Campus, Cambridge UK',
#        'contact_name': 'Roser,,Veno-Tormo',
#        'country': 'UK',
#        'email': 'rv4@sanger.ac.uk',
#        'institution': 'Wellcome Trust Sanger Institute',
#        'laboratory': 'Sarah Teichmann'},
#       {'address': 'Wellcome Trust Genome Campus, Cambridge UK',
#        'contact_name': 'Jhuma,,Pramanik',
#        'country': 'UK',
#        'email': 'jp19@sanger.ac.uk',
#        'institution': 'Wellcome Trust Sanger Institute',
#        'laboratory': 'Sarah Teichmann'},
#       {'address': 'Wellcome Trust Genome Campus, Cambridge UK',
#        'contact_name': 'Gozde,,Kar',
#        'country': 'UK',
#        'email': 'gkar@ebi.ac.uk',
#        'institution': 'EMBL-EBI',
#        'laboratory': 'Sarah Teichmann'},
#       {'contact_name': 'Jani,,Huuhtanen',
#        'country': 'Finland',
#        'email': 'jani.huuhtanen@helsinki.fi',
#        'institution': 'University of Helsinki'}],
#      'describedBy': 'https://schema.humancellatlas.org/type/project/5.1.0/project',
#      'project_core': {'project_description': 'The cancer microenvironment is a complex ecosystem characterized by dynamic interactions between diverse cell types, including malignant, immune and stromal cells. Here, we performed single-cell RNA sequencing on CD45+ and CD45- cells isolated from tumour and lymph nodes during a mouse model of melanoma. The transcriptional profiles of these individual cells taken at different time points coupled with assembled T cell receptor sequences, allowed us to identify distinct immune subpopulations and delineate their developmental trajectory. Our study provides insights into the complex interplay among cells within the tumour microenvironment and presents a valuable resource for future translational applications.',
#       'project_shortname': 'Mouse Melanoma',
#       'project_title': 'Melanoma infiltration of stromal and immune cells'},
#      'publications': [],
#      'schema_type': 'project'},
#     'describedBy': 'https://schema.humancellatlas.org/bundle/5.1.0/project',
#     'hca_ingest': {'accession': '',
#      'document_id': '93f6a42f-1790-4af4-b5d1-8c436cb6feae',
#      'submissionDate': '2018-03-28T13:55:26.025Z',
#      'updateDate': '2018-03-28T14:27:32.460Z'},
#     'schema_type': 'project_bundle',
#     'schema_version': '5.1.0'},
#    'protocol_json': {'describedBy': 'https://schema.humancellatlas.org/bundle/5.1.0/protocol',
#     'protocols': [{'content': {'describedBy': 'https://schema.humancellatlas.org/type/protocol/5.1.0/protocol',
#        'protocol_core': {'document': 'TissueDissociationProtocol.pdf',
#         'protocol_id': 'tissue_dissociation_protocol',
#         'protocol_name': 'Extracting cells from lymph nodes'},
#        'schema_type': 'protocol'},
#       'hca_ingest': {'accession': '',
#        'document_id': 'c9a1e203-bddc-45d3-87c4-6010be8e0127',
#        'submissionDate': '2018-03-28T13:55:26.033Z',
#        'updateDate': '2018-03-28T14:14:33.716Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/protocol/5.1.0/protocol',
#        'protocol_core': {'document': 'FACSsortingProtocol.pdf',
#         'protocol_id': 'FACS_sorting_protocol',
#         'protocol_name': 'FACS sorting cells by surface markers'},
#        'schema_type': 'protocol'},
#       'hca_ingest': {'accession': '',
#        'document_id': 'a1c80daf-58b0-4b7a-8e29-d0130493c8e6',
#        'submissionDate': '2018-03-28T13:55:26.040Z',
#        'updateDate': '2018-03-28T14:45:43.500Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/protocol/5.1.0/protocol',
#        'protocol_core': {'document': 'SmartSeq2_RTPCR_protocol.pdf',
#         'protocol_id': 'SmartSeq2_RTPCR_protocol',
#         'protocol_name': 'Make/amplify cDNA for each cell'},
#        'protocol_type': {'ontology': 'EFO:0008442',
#         'text': 'Smart-seq2 protocol'},
#        'schema_type': 'protocol'},
#       'hca_ingest': {'accession': '',
#        'document_id': '52d79a89-4b49-4c1b-b857-5cc5da07f643',
#        'submissionDate': '2018-03-28T13:55:26.044Z',
#        'updateDate': '2018-03-28T14:24:04.790Z'}},
#      {'content': {'describedBy': 'https://schema.humancellatlas.org/type/protocol/5.1.0/protocol',
#        'protocol_core': {'protocol_id': 'SmartSeq2_sequencing_protocol',
#         'protocol_name': 'Sequencing SmartSeq2 cells'},
#        'schema_type': 'protocol'},
#       'hca_ingest': {'accession': '',
#        'document_id': 'ca6096cf-13c1-4930-8308-6ab05865e2c9',
#        'submissionDate': '2018-03-28T13:55:26.050Z',
#        'updateDate': '2018-03-28T14:30:39.321Z'}}],
#     'schema_type': 'protocol_bundle',
#     'schema_version': '5.1.0'}},
#   'manifest': {'creator_uid': 8008,
#    'files': [{'content-type': 'application/json; dcp-type="metadata/project"',
#      'crc32c': 'aa2dfbb1',
#      'indexed': True,
#      'name': 'project.json',
#      's3-etag': '066f4af443f5db0e1d893bcee16db0e6',
#      'sha1': 'fe667c736c9cbc5b129905cc04609d3f5b9a8caa',
#      'sha256': 'df3e4f52d63201bc1c9f47af0a6717187b3d4d8f82213bf87dcf79440e93cfec',
#      'size': 4798,
#      'uuid': 'b4bbcb5f-f6d8-4c80-ba38-5d67871a7323',
#      'version': '2018-03-29T141750.370101Z'},
#     {'content-type': 'application/json; dcp-type="metadata/biomaterial"',
#      'crc32c': 'fcdff238',
#      'indexed': True,
#      'name': 'biomaterial.json',
#      's3-etag': 'c80c4b9096eddfd21048e97ef70a4987',
#      'sha1': 'dc98114dcfa8057de895916494a73ee54fdd9d1e',
#      'sha256': '24e3c750767fc39d84f344e7a832c6650b12e6ca18018dc1fa456e1ff9dd6d07',
#      'size': 4206,
#      'uuid': 'b84029b4-0ed8-406b-88fc-24b97c41cfcb',
#      'version': '2018-03-29T141750.837721Z'},
#     {'content-type': 'application/gzip; dcp-type=data',
#      'crc32c': '53d1617c',
#      'indexed': False,
#      'name': '22011_1#68_1.fastq.gz',
#      's3-etag': 'a9446896a0dd0f9109d087f2b6dec066-2',
#      'sha1': 'fce8a9225ec443bac39c84f1502afb6344b690f5',
#      'sha256': 'fb0a78c5f7991196f5d44f5d3c7e99bebcefa3a54cc2c0cadd497c7a03614fb1',
#      'size': 71404310,
#      'uuid': '7991a95b-3f58-413e-bdb0-9516c7429cd4',
#      'version': '2018-03-29T141751.431155Z'},
#     {'content-type': 'application/gzip; dcp-type=data',
#      'crc32c': '42a0d6b1',
#      'indexed': False,
#      'name': '22011_1#68_2.fastq.gz',
#      's3-etag': '9340902cc0e6420da47f22b0482411f0-2',
#      'sha1': 'a5239886a2bd74ad92f071b4ec28d36c0c1d7c74',
#      'sha256': '9939ce929c54bac739e78a03867a897fe0f8c9287e5b3406deb0b684fc0d5822',
#      'size': 86072697,
#      'uuid': 'd1aec1c7-0005-4d51-9b94-84aa7149fd1b',
#      'version': '2018-03-29T141752.230684Z'},
#     {'content-type': 'application/json; dcp-type="metadata/file"',
#      'crc32c': '08f13e93',
#      'indexed': True,
#      'name': 'file.json',
#      's3-etag': '4d04716487c4b5dc46e1c2e651b68b04',
#      'sha1': 'a9fdb3450e5332ebbd5781cc8caa24b85481c45f',
#      'sha256': '8f639d78b402cbeca4ddf104d74544acb7384c53c7c497ca008f6c72e8ef91f0',
#      'size': 1374,
#      'uuid': 'aae375e4-2f46-4fa7-a947-df5470f1f1f6',
#      'version': '2018-03-29T141752.807692Z'},
#     {'content-type': 'application/json; dcp-type="metadata/process"',
#      'crc32c': '2489e51b',
#      'indexed': True,
#      'name': 'process.json',
#      's3-etag': 'daeb3354ee4359a5d67242cc0713f40d',
#      'sha1': '3ce37b04dc4f4bd22e4c02facad118a6cd0c124c',
#      'sha256': 'b06e36a77917407299ae900496f3e5e878efdc04d1db8443b90855d8342a4178',
#      'size': 5808,
#      'uuid': '66e17d5d-c074-4dc5-a237-db6d1e1ee8a6',
#      'version': '2018-03-29T141754.027944Z'},
#     {'content-type': 'application/json; dcp-type="metadata/protocol"',
#      'crc32c': 'ce01b7a3',
#      'indexed': True,
#      'name': 'protocol.json',
#      's3-etag': '43344cd080486f596a4de622631d2d93',
#      'sha1': 'b4407c8f8ddb3610f756d2d845b12612f2ea9835',
#      'sha256': '55a766a6a67c67dbfc021653d4a7e1b58e083dcff6f3d5c8e7fb122f8fd6926d',
#      'size': 3174,
#      'uuid': '3a20f4f4-6783-43e0-a52b-9576596e6c8a',
#      'version': '2018-03-29T141755.134883Z'},
#     {'content-type': 'application/json; dcp-type="metadata/links"',
#      'crc32c': 'b1f519f5',
#      'indexed': True,
#      'name': 'links.json',
#      's3-etag': 'f4c69ed67e777e62445d5e2fbbd3c7e2',
#      'sha1': '071acf540b80e44907c54e1cd8ce0b610801e1b1',
#      'sha256': '0c141149fdd26c71787a547169ad717f3f2216ef3f0c0be1f6af574e32e50da2',
#      'size': 7213,
#      'uuid': 'e2c645dc-5222-404d-a958-1cb2946c89a6',
#      'version': '2018-03-29T141755.574658Z'}],
#    'format': '0.0.1',
#    'version': '2018-03-29T141756.401707Z'},
#   'state': 'new',
#   'uuid': '1e352213-af04-4678-b659-f245e924a888'},
#  'search_score': 1.0}

# %% [markdown]
# There we go! It's not very pretty, but now that we know where the `total_estimated_cells` and `organ` fields lie, we can finish our ElasticSearch query.

# %%
query = {
    "query" : {
        "bool" : {
            "must" : [{
                "match" : {
                    "files.biomaterial_json.biomaterials.content.organ.text" : organ_type
                }
            }, {
                "range" : {
                    "files.biomaterial_json.biomaterials.content.total_estimated_cells" : {
                        "gt" : 0
                    }
                }
            }]
        }
    }
}

# %% [markdown]
# Now, let's see if this returns any results. Instead of using a `raw` `output_format` here, let's just use the default, `summary`, for simplicity (since all we need from our search is the total number of hits).

# %%
client.post_search(es_query=query, replica='aws')['total_hits']
# Out:
# 4

# %% [markdown]
# Great, we got something. It looks like we have 4 bundles containing at least one hematopoietic system cell. Now we just need to add them up.

# %%
count = 0

# Iterate through all search results containing the chosen cell type
for bundle in client.post_search.iterate(es_query=query, replica='aws', output_format='raw'):
    count += bundle['metadata']['files']['biomaterial_json']['biomaterials'][0]['content']['total_estimated_cells']

print('{} cell count: {}'.format(organ_type, count))
# Out:
# hematopoietic system cell count: 17397

# %% [markdown]
# Alright, it looks like we're done here. Our program returned 17397 cells total out of the four bundles we searched.
