# %% [markdown]
# **N.B**: This notebook doesn't point to the "real" HCA Data Coordination Platform. It points to an instance of the Data Storage System used for testing. So, you won't find this data in the future, and its organization and metadata structure won't necessarily match what's available in the DCP.
#
# This is especially true for anything regarding expression matrices. The formats, metadata, and APIs for expression matrices are under active development, and feedback and ideas are welcome. Nevertheless, the examples below can be useful for exploring the API and data model conceptually.

# %% [markdown]
# ## Indexed Metadata
#
# The [Investigate a Bundle](Investigate a Bundle.ipynb) notebook walked through the contents of a bundle (and you probably should step through it before looking at this notebook). There we started with a bundle uuid, but what if we wanted to find that bundle uuid based on some facts we knew about the bundle?
#
# Recall the bundle we were looking at:

# %%
import hca.dss
dss_client = hca.dss.DSSClient()
bundle_uuid = 'ec7e6476-abeb-4d78-82d8-8a28b43c46a6'
bundle = dss_client.get_bundle(uuid=bundle_uuid, replica="aws")
bundle
# Out:
# {'bundle': {'creator_uid': 8008,
#   'files': [{'content-type': 'application/json; dcp-type="metadata/project"',
#     'crc32c': '4ce66be3',
#     'indexed': True,
#     'name': 'project.json',
#     's3_etag': '2be0a2479191779505af379eba6d5d10',
#     'sha1': '36a9ab5c9cf6d772e52310740ce55ed09eb2dd19',
#     'sha256': '76106f0ac8250169e75f1034192cec634ac395c99a912a9be9b8496782f6e6f4',
#     'size': 2714,
#     'uuid': '370452fa-3091-48cb-8d69-10c26e0db433',
#     'version': '2018-03-26T154205.186524Z'},
#    {'content-type': 'application/json; dcp-type="metadata/biomaterial"',
#     'crc32c': 'b1c5b387',
#     'indexed': True,
#     'name': 'biomaterial.json',
#     's3_etag': '8a3359dcb4c38b24f648d9168a8fea64',
#     'sha1': 'd43bbe3baf4e3fabb7f5d4bc0c062429027dd28d',
#     'sha256': '7ca86a30655aedc6c00a34b1768d529459740a14c989acfd4552fb660493a6bd',
#     'size': 3700,
#     'uuid': '1d7fd92c-ae01-4920-91a9-3edf950d4d70',
#     'version': '2018-03-26T154205.786705Z'},
#    {'content-type': 'application/gzip; dcp-type=data',
#     'crc32c': '66fcd7a4',
#     'indexed': False,
#     'name': 'SRR3934437_1.fastq.gz',
#     's3_etag': 'bd554b6cca01f86f0ff0049adf740f35',
#     'sha1': 'f5ab7e592461e0fb7b7293b4a089cc144f12bd80',
#     'sha256': '0685d2f3a2606892437979db49da4b08e444d784bdc2545b6935d4da997aab7a',
#     'size': 46620992,
#     'uuid': 'b589faf3-1193-4427-a256-e10eb17fdd13',
#     'version': '2018-03-26T154206.570819Z'},
#    {'content-type': 'application/gzip; dcp-type=data',
#     'crc32c': '66e59b01',
#     'indexed': False,
#     'name': 'SRR3934437_2.fastq.gz',
#     's3_etag': '321fccb6569ff505495cb34a33e1c9a3',
#     'sha1': '577738cdfcb4220520f9ba1ee9b6845e282db016',
#     'sha256': 'e562982c2142427596d1cbc6612491584e5123bdd29dc539e166fa976dfc9552',
#     'size': 49310595,
#     'uuid': 'b968bf89-f6a8-4fd2-9bc1-8dd25d4c85c9',
#     'version': '2018-03-26T154208.067192Z'},
#    {'content-type': 'application/json; dcp-type="metadata/file"',
#     'crc32c': '48a6673b',
#     'indexed': True,
#     'name': 'file.json',
#     's3_etag': 'cd65d78ee7e506c21c8b9d31f21a5f47',
#     'sha1': 'fc52615dd72640ed36f51eb71eccd8f624b59a88',
#     'sha256': '72b2a010839043b26cca79d6efdcc45aeeae1cc3f77023b1b1dca7cd61583261',
#     'size': 1306,
#     'uuid': '0cf13def-5d60-42ca-a62c-a3daeb2298f1',
#     'version': '2018-03-26T154210.763649Z'},
#    {'content-type': 'application/json; dcp-type="metadata/process"',
#     'crc32c': '7367e083',
#     'indexed': True,
#     'name': 'process.json',
#     's3_etag': '7388f14f7ba2abbad5dc6ee0cd16d856',
#     'sha1': 'fe0b9a26cba7b9d5879776564184c62d7354d63f',
#     'sha256': '811f46638a14fc611dd34e621dce0c0396baae0b8a5ec48122f7337343dc8833',
#     'size': 3394,
#     'uuid': '054ae44b-2222-477a-995a-27e2b6c83258',
#     'version': '2018-03-26T154211.750783Z'},
#    {'content-type': 'application/json; dcp-type="metadata/protocol"',
#     'crc32c': 'dad141fd',
#     'indexed': True,
#     'name': 'protocol.json',
#     's3_etag': 'b0c0980cc8a196b1e7236a889a19d0f8',
#     'sha1': '8966e992716590e9a37123e676c3a7b7e713635a',
#     'sha256': 'f5253f8bc4609997681b9bb0c1b299b04cdf48b8d6f29fd72cdc0682815ec8b9',
#     'size': 2388,
#     'uuid': '64629b4a-d70e-4eb0-a7a5-e4a4a9e8f86b',
#     'version': '2018-03-26T154212.576715Z'},
#    {'content-type': 'application/json; dcp-type="metadata/links"',
#     'crc32c': 'e45cf235',
#     'indexed': True,
#     'name': 'links.json',
#     's3_etag': '0c9586ee1010f9318d8715a9fa75eabd',
#     'sha1': '83846aa571e40700a98764b3e3dd6945e75aae63',
#     'sha256': 'c77d2479c27036629776ef259e9af3204fac6b551c044f5b3589a8eeec3858d8',
#     'size': 3463,
#     'uuid': '1fee11bf-1873-422a-bc50-016e22bffd21',
#     'version': '2018-03-26T154213.160405Z'}],
#   'uuid': 'ec7e6476-abeb-4d78-82d8-8a28b43c46a6',
#   'version': '2018-03-26T154214.008924Z'}}

# %% [markdown]
# And recall that bundle contained some json files, one of which was `biomaterial.json`. If you look at the contents of the bundle, you can see that that file has an `"indexed": True` field, which means that the contents of that file can be searched. So let's look at the contents of `biomaterial.json` again:

# %%
biomaterial_json_uuid = [f['uuid'] for f in bundle['bundle']['files'] if f['name'] == 'biomaterial.json'][0]
dss_client.get_file(uuid=biomaterial_json_uuid, replica="aws")
# Out:
# {'biomaterials': [{'content': {'biomaterial_core': {'has_input_biomaterial': 'BT_S2_T',
#      'biomaterial_name': 'Single cell from Tumor,1001000174.A2',
#      'supplementary_files': ['ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2243nnn/GSM2243527/suppl/GSM2243527_1001000174.A2.csv.gz'],
#      'ncbi_taxon_id': [9606],
#      'biomaterial_id': 'GSM2243527',
#      'biosd_biomaterial': 'SAMN05421306'},
#     'genus_species': [{'text': 'Homo sapiens', 'ontology': 'NCBITaxon:9606'}],
#     'describedBy': 'https://schema.humancellatlas.org/type/biomaterial/5.1.0/cell_suspension',
#     'total_estimated_cells': 1,
#     'schema_type': 'biomaterial'},
#    'hca_ingest': {'accession': '',
#     'submissionDate': '2018-03-22T10:14:35.739Z',
#     'updateDate': '2018-03-22T10:19:26.105Z',
#     'document_id': '64ad6b33-66d0-46f0-a34d-283ca8ae5978'}},
#   {'content': {'organ': {'text': 'brain', 'ontology': 'UBERON:0000955'},
#     'genus_species': [{'text': 'Homo sapiens', 'ontology': 'NCBITaxon:9606'}],
#     'schema_type': 'biomaterial',
#     'biomaterial_core': {'has_input_biomaterial': 'BT_S2',
#      'ncbi_taxon_id': [9606],
#      'biomaterial_id': 'BT_S2_T',
#      'biomaterial_description': 'Tumor'},
#     'organ_part': {'text': 'temporal lobe'},
#     'describedBy': 'https://schema.humancellatlas.org/type/biomaterial/5.1.0/specimen_from_organism'},
#    'hca_ingest': {'accession': '',
#     'submissionDate': '2018-03-22T10:14:32.451Z',
#     'updateDate': '2018-03-22T10:17:39.231Z',
#     'document_id': '6253cba6-f6f8-48c0-85a8-c65ed3f4e87a'}},
#   {'content': {'is_living': True,
#     'biological_sex': 'unknown',
#     'genus_species': [{'text': 'Homo sapiens', 'ontology': 'NCBITaxon:9606'}],
#     'schema_type': 'biomaterial',
#     'biomaterial_core': {'ncbi_taxon_id': [9606], 'biomaterial_id': 'BT_S2'},
#     'describedBy': 'https://schema.humancellatlas.org/type/biomaterial/5.1.0/donor_organism'},
#    'hca_ingest': {'accession': '',
#     'submissionDate': '2018-03-22T10:15:09.762Z',
#     'updateDate': '2018-03-22T10:17:07.810Z',
#     'document_id': 'e169ba60-4a7f-4832-98de-2a8a1555108e'}}],
#  'describedBy': 'https://schema.humancellatlas.org/bundle/5.1.0/biomaterial',
#  'schema_version': '5.1.0',
#  'schema_type': 'biomaterial_bundle'}

# %% [markdown]
# There are a number of things in there that we could search for, but let's say we want to find bundles associated with that `biomaterial_id`, `BT_S2_T`

# %%
es_query = {
    "query": {
        "term": {
            "files.biomaterial_json.biomaterials.content.biomaterial_core.biomaterial_id": "BT_S2_T"
        }
    }
}
result = dss_client.post_search(replica="aws", es_query=es_query)
print(result["total_hits"])
result
# Out:
# 5613
# {'es_query': {'query': {'term': {'files.biomaterial_json.biomaterials.content.biomaterial_core.biomaterial_id': 'BT_S2_T'}}},
#  'results': [{'bundle_fqid': '01cd1cb1-dabf-4d96-9534-9a5c3182ff37.2018-03-26T154145.331261Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/01cd1cb1-dabf-4d96-9534-9a5c3182ff37?version=2018-03-26T154145.331261Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': 
z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': 'c2724a56-88c1-4ada-a09f-ebaf8d1a36ac.2018-03-26T154755.258394Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/c2724a56-88c1-4ada-a09f-ebaf8d1a36ac?version=2018-03-26T154755.258394Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': 'c23f5d66-704f-4feb-9072-ce78d5877cf6.2018-03-26T154745.030995Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/c23f5d66-704f-4feb-9072-ce78d5877cf6?version=2018-03-26T154745.030995Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': '08fa4244-30a5-41a9-bd50-53e2f3562d49.2018-03-26T154752.656646Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/08fa4244-30a5-41a9-bd50-53e2f3562d49?version=2018-03-26T154752.656646Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': '202a6cfa-6548-4329-bd09-810ad3cab55d.2018-03-26T154740.177563Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/202a6cfa-6548-4329-bd09-810ad3cab55d?version=2018-03-26T154740.177563Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': 'f0eb8528-9c6c-4fa7-8d86-4d412022880c.2018-03-26T154739.377935Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/f0eb8528-9c6c-4fa7-8d86-4d412022880c?version=2018-03-26T154739.377935Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': 'f3c4ab07-b71b-4c3d-a291-4ffabb5189e7.2018-03-26T154826.641517Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/f3c4ab07-b71b-4c3d-a291-4ffabb5189e7?version=2018-03-26T154826.641517Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': '3277ec5e-5cae-4734-830c-ec79998c88bb.2018-03-26T154826.710043Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/3277ec5e-5cae-4734-830c-ec79998c88bb?version=2018-03-26T154826.710043Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': '1518671b-f143-466d-8b70-2cbfe59eb672.2018-03-26T154809.712362Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/1518671b-f143-466d-8b70-2cbfe59eb672?version=2018-03-26T154809.712362Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': '46d58466-919a-47dc-8b05-35a79a4b1786.2018-03-26T154810.441289Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/46d58466-919a-47dc-8b05-35a79a4b1786?version=2018-03-26T154810.441289Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': 'b1053d70-c9ef-4fee-b4fb-8dc9a1caf477.2018-03-26T154817.035843Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/b1053d70-c9ef-4fee-b4fb-8dc9a1caf477?version=2018-03-26T154817.035843Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': 'c913875f-2f74-4cba-8e36-f06c2d3eec75.2018-03-26T154817.870358Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/c913875f-2f74-4cba-8e36-f06c2d3eec75?version=2018-03-26T154817.870358Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': '287e3779-1ecc-4f62-a0ea-e2107ba41550.2018-03-26T154825.344411Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/287e3779-1ecc-4f62-a0ea-e2107ba41550?version=2018-03-26T154825.344411Z&replica=aws',
#    'search_score': 0.74350744},
#   {'bundle_fqid': '335f0dbc-2940-49c0-a172-05d4e3343a2a.2018-03-26T154757.633895Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/335f0dbc-2940-49c0-a172-05d4e3343a2a?version=2018-03-26T154757.633895Z&replica=aws',
#    'search_score': 0.74350744}],
#  'total_hits': 5613}

# %% [markdown]
# That worked a little too well. We found 5613 bundles that contain that `biomaterial_id`. It would be great if the uuid we're looking for was in there:

# %%
bundle_uuid in (r["bundle_fqid"][:36] for r in dss_client.post_search.iterate(replica="aws", es_query=es_query))
# Out:
# True

# %% [markdown]
# Promising! Also, note a couple changes in that function call. First, we used `post_search.iterate` to return a generator over all the query results. If we just used `post_search`, we would only get the first page of 100 query results.
#
# The query also returned a "bundle_fqid", a fully-qualified bundle id. That included both the bundle uuid and the version, so we use `[:36]` to strip off the version.
#
# Now, we can make our query more specific by adding some other contraints:

# %%
es_query = {
    "query": {
        "bool": {
            "must": [
                {
                    "term": {
                        "files.biomaterial_json.biomaterials.content.biomaterial_core.biomaterial_id": "BT_S2_T"
                    }
                },
                {
                    "term": {
                        "files.file_json.files.content.file_core.file_name": "SRR3934437_2.fastq.gz"
                    }
                }
            ]
        }
    }
}
result = dss_client.post_search(replica="aws", es_query=es_query)
print(result["total_hits"])
result
# Out:
# 8
# {'es_query': {'query': {'bool': {'must': [{'term': {'files.biomaterial_json.biomaterials.content.biomaterial_core.biomaterial_id': 'BT_S2_T'}},
#      {'term': {'files.file_json.files.content.file_core.file_name': 'SRR3934437_2.fastq.gz'}}]}}},
#  'results': [{'bundle_fqid': '1ec1f360-4132-426f-bb02-1337be74340d.2018-03-26T205712.928298Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/1ec1f360-4132-426f-bb02-1337be74340d?version=2018-03-26T205712.928298Z&replica=aws',
#    'search_score': 7.523884},
#   {'bundle_fqid': '7a533bfc-c99a-4f50-8d28-0257c59b53d1.2018-04-09T144329.633297Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/7a533bfc-c99a-4f50-8d28-0257c59b53d1?version=2018-04-09T144329.633297Z&replica=aws',
#    'search_score': 7.523884},
#   {'bundle_fqid': 'f3959034-e93b-4b28-8f40-82d8bcccf10b.2018-03-26T212152.807357Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/f3959034-e93b-4b28-8f40-82d8bcccf10b?version=2018-03-26T212152.807357Z&replica=aws',
#    'search_score': 7.4910817},
#   {'bundle_fqid': 'df125f53-eddf-446e-9217-79550a921a8c.2018-03-28T104554.289151Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/df125f53-eddf-446e-9217-79550a921a8c?version=2018-03-28T104554.289151Z&replica=aws',
#    'search_score': 7.4910817},
#   {'bundle_fqid': 'ec7e6476-abeb-4d78-82d8-8a28b43c46a6.2018-03-26T154214.008924Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/ec7e6476-abeb-4d78-82d8-8a28b43c46a6?version=2018-03-26T154214.008924Z&replica=aws',
#    'search_score': 6.8910937},
#   {'bundle_fqid': '2a606903-bc1b-4ebc-a9ee-73c345b593a1.2018-03-26T181519.144501Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/2a606903-bc1b-4ebc-a9ee-73c345b593a1?version=2018-03-26T181519.144501Z&replica=aws',
#    'search_score': 6.8910937},
#   {'bundle_fqid': '8d96d3f4-4829-407f-a10e-2250ab7b4cc9.2018-03-26T214344.920356Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/8d96d3f4-4829-407f-a10e-2250ab7b4cc9?version=2018-03-26T214344.920356Z&replica=aws',
#    'search_score': 6.8910937},
#   {'bundle_fqid': '16d7964b-71a5-45f5-95b5-922c2cabaac9.2018-04-06T124838.289336Z',
#    'bundle_url': 'https://dss.integration.data.humancellatlas.org/v1/bundles/16d7964b-71a5-45f5-95b5-922c2cabaac9?version=2018-04-06T124838.289336Z&replica=aws',
#    'search_score': 6.8910937}],
#  'total_hits': 8}

# %% [markdown]
# Well okay, eight bundles. This is a test environment, so there are some bundles uploaded multiple times. But, our desired bundle id, `ec7e6476-abeb-4d78-82d8-8a28b43c46a6` is there.
