# %% [markdown]
# # Sum of All Brain Cells
#
# I need to find how many cells of a certain organ type are available in the HCA database. How can I go about doing this?
#
# First, let's get set up.

# %%
import hca.dss
client = hca.dss.DSSClient()

client.host = 'https://dss.staging.data.humancellatlas.org/v1'

# %% [markdown]
# Now, what type of cells are we looking for? Maybe brain cells?

# %%
organ_type = 'brain'

# %% [markdown]
# To find what cells appear in the database, we'll need to do some _searching_: specifically, using the __post_search()__ method. `post_search()` has four parameters: `es_query`, `output_format`, `replica`, and `per_page`, two of which are optional: `output_format` and `per_page`.
#
# Let's not worry about `per_page`; we won't be needing it for this. For `replica`, we'll be using AWS, and for `output_format`, we'll want to use the mode `raw`. Using `raw` will return get the verbatim JSON metadata for bundles that match our query, which we'll need in order to view the organ type.
#
# Assuming we don't know what the fields in our ElasticSearch query will look like, we can start by searching for those first. Our query should find all bundles that are of the organ type "brain" and also include a cell count. In the end, it should look something like this:
#
# ```json
# query = {
#     "query" : {
#         "bool" : {
#             "must" : [
#                 {
#                     "match" : {
#                         "some.path.to.the.organ.type" : organ_type
#                     }
#                 },
#                 {
#                     "exists" : { "field" : "some.path.to.the.cell.count" }
#                 }
#             ]
#         }
#     }
# }
# ```
#
# To find these fields, we can just look at some arbitrary bundle in its `raw` form. Let's do a search over everything to find one. Notice that I'm using the `json` Python module so that our results print nicely.

# %%
import json

results = client.post_search(es_query={}, replica='aws', output_format='raw')['results'][0]
print(json.dumps(results, indent=4, sort_keys=True))
# Out:
# {
#     "bundle_fqid": "02be9959-4616-4f24-ad30-c5f0611694e6.2018-11-13T165615.841022Z",
#     "bundle_url": "https://dss.staging.data.humancellatlas.org/v1/bundles/02be9959-4616-4f24-ad30-c5f0611694e6?version=2018-11-13T165615.841022Z&replica=aws",
#     "metadata": {
#         "files": {
#             "analysis_file_json": [
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "tsv",
#                         "file_name": "barcodes.tsv"
#                     },
#                     "provenance": {
#                         "document_id": "56307381-7bf5-472f-9d90-d1ee73675932",
#                         "submission_date": "2018-11-13T16:49:57.454Z",
#                         "update_date": "2018-11-13T16:52:51.181Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "tsv",
#                         "file_name": "genes.tsv"
#                     },
#                     "provenance": {
#                         "document_id": "e07c6f55-509f-4e07-b6ea-88b03ac4dbce",
#                         "submission_date": "2018-11-13T16:49:57.543Z",
#                         "update_date": "2018-11-13T16:52:54.187Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "mtx",
#                         "file_name": "matrix.mtx"
#                     },
#                     "provenance": {
#                         "document_id": "d8c11c8b-a8a2-425d-b839-c7be1a29fc51",
#                         "submission_date": "2018-11-13T16:49:57.631Z",
#                         "update_date": "2018-11-13T16:52:54.185Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "h5",
#                         "file_name": "filtered_gene_bc_matrices_h5.h5"
#                     },
#                     "provenance": {
#                         "document_id": "93d5756e-5d7f-4521-9b8e-0347f1f1984d",
#                         "submission_date": "2018-11-13T16:49:57.716Z",
#                         "update_date": "2018-11-13T16:52:57.182Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "csv",
#                         "file_name": "metrics_summary.csv"
#                     },
#                     "provenance": {
#                         "document_id": "ed7ae77f-3931-4a02-aef0-febda5ad4400",
#                         "submission_date": "2018-11-13T16:49:57.800Z",
#                         "update_date": "2018-11-13T16:52:48.178Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "h5",
#                         "file_name": "molecule_info.h5"
#                     },
#                     "provenance": {
#                         "document_id": "12ce9831-e48c-448e-8a4c-0923c020d31e",
#                         "submission_date": "2018-11-13T16:49:57.888Z",
#                         "update_date": "2018-11-13T16:53:00.182Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "bam",
#                         "file_name": "possorted_genome_bam.bam"
#                     },
#                     "provenance": {
#                         "document_id": "40f703ec-a6c9-48c3-ba46-c348f2b4476d",
#                         "submission_date": "2018-11-13T16:49:57.973Z",
#                         "update_date": "2018-11-13T16:52:54.187Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "bai",
#                         "file_name": "possorted_genome_bam.bam.bai"
#                     },
#                     "provenance": {
#                         "document_id": "3edf5182-694a-4090-bf02-51ac23b3c9ee",
#                         "submission_date": "2018-11-13T16:49:58.056Z",
#                         "update_date": "2018-11-13T16:52:51.181Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "h5",
#                         "file_name": "raw_gene_bc_matrices_h5.h5"
#                     },
#                     "provenance": {
#                         "document_id": "b90c2ea5-6a20-41b3-921e-b7e17a25a54b",
#                         "submission_date": "2018-11-13T16:49:58.138Z",
#                         "update_date": "2018-11-13T16:52:57.182Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "unknown",
#                         "file_name": "web_summary.html"
#                     },
#                     "provenance": {
#                         "document_id": "5024ce72-e49a-4cc6-a141-9f30f0e19680",
#                         "submission_date": "2018-11-13T16:49:58.225Z",
#                         "update_date": "2018-11-13T16:53:00.182Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "tsv",
#                         "file_name": "raw_barcodes.tsv"
#                     },
#                     "provenance": {
#                         "document_id": "81104335-7f3a-4a44-a0dd-8f23810dd073",
#                         "submission_date": "2018-11-13T16:49:58.309Z",
#                         "update_date": "2018-11-13T16:53:03.180Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "tsv",
#                         "file_name": "raw_genes.tsv"
#                     },
#                     "provenance": {
#                         "document_id": "f5e19e2c-19c9-4728-b445-4bf34f6f7fc9",
#                         "submission_date": "2018-11-13T16:49:58.394Z",
#                         "update_date": "2018-11-13T16:53:03.179Z"
#                     },
#                     "schema_type": "file"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                     "file_core": {
#                         "file_format": "mtx",
#                         "file_name": "raw_matrix.mtx"
#                     },
#                     "provenance": {
#                         "document_id": "0991f785-3ba6-4599-adb4-d984a5e8bcc1",
#                         "submission_date": "2018-11-13T16:49:58.482Z",
#                         "update_date": "2018-11-13T16:53:06.175Z"
#                     },
#                     "schema_type": "file"
#                 }
#             ],
#             "analysis_process_json": [
#                 {
#                     "analysis_run_type": "run",
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/process/analysis/8.0.3/analysis_process",
#                     "input_bundles": [
#                         "1542db7c-678a-4139-be14-a45a6f34ab23"
#                     ],
#                     "inputs": [
#                         {
#                             "parameter_name": "fastqs",
#                             "parameter_value": "gs://org-humancellatlas-dss-checkout-staging/bundles/1542db7c-678a-4139-be14-a45a6f34ab23.2018-11-13T161441.718477Z/pbmc4k_S1_L001_R1_001.fastq.gz, gs://org-humancellatlas-dss-checkout-staging/bundles/1542db7c-678a-4139-be14-a45a6f34ab23.2018-11-13T161441.718477Z/pbmc4k_S1_L001_R2_001.fastq.gz, gs://org-humancellatlas-dss-checkout-staging/bundles/1542db7c-678a-4139-be14-a45a6f34ab23.2018-11-13T161441.718477Z/pbmc4k_S1_L001_I1_001.fastq.gz"
#                         },
#                         {
#                             "parameter_name": "sample_id",
#                             "parameter_value": "ca5de32f-636a-4862-a7f6-f755a5b8d85d"
#                         },
#                         {
#                             "parameter_name": "reference_name",
#                             "parameter_value": "GRCh38"
#                         },
#                         {
#                             "parameter_name": "transcriptome_tar_gz",
#                             "parameter_value": "gs://hca-dcp-mint-test-data/reference/GRCh38_Gencode/GRCh38_GencodeV27_Primary_CellRanger.tar"
#                         },
#                         {
#                             "parameter_name": "expect_cells",
#                             "parameter_value": "5000"
#                         }
#                     ],
#                     "outputs": [
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "tsv",
#                                 "file_name": "barcodes.tsv"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "tsv",
#                                 "file_name": "genes.tsv"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "mtx",
#                                 "file_name": "matrix.mtx"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "h5",
#                                 "file_name": "filtered_gene_bc_matrices_h5.h5"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "csv",
#                                 "file_name": "metrics_summary.csv"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "h5",
#                                 "file_name": "molecule_info.h5"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "bam",
#                                 "file_name": "possorted_genome_bam.bam"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "bai",
#                                 "file_name": "possorted_genome_bam.bam.bai"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "h5",
#                                 "file_name": "raw_gene_bc_matrices_h5.h5"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "unknown",
#                                 "file_name": "web_summary.html"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "tsv",
#                                 "file_name": "raw_barcodes.tsv"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "tsv",
#                                 "file_name": "raw_genes.tsv"
#                             },
#                             "schema_type": "file"
#                         },
#                         {
#                             "describedBy": "http://schema.staging.data.humancellatlas.org/type/file/5.3.4/analysis_file",
#                             "file_core": {
#                                 "file_format": "mtx",
#                                 "file_name": "raw_matrix.mtx"
#                             },
#                             "schema_type": "file"
#                         }
#                     ],
#                     "process_core": {
#                         "process_id": "d0ee5b5e-c138-4eb9-b46a-d4e4626105a3"
#                     },
#                     "process_type": {
#                         "text": "analysis"
#                     },
#                     "provenance": {
#                         "document_id": "98ee9a53-89c3-4e01-b2d2-d9925e8aee53",
#                         "submission_date": "2018-11-13T16:49:57.121Z",
#                         "update_date": "2018-11-13T16:50:03.286Z"
#                     },
#                     "reference_bundle": "bf51d668-3e14-4843-9bc7-5d676fdf0e01",
#                     "schema_type": "process",
#                     "tasks": [
#                         {
#                             "cpus": 64,
#                             "disk_size": "local-disk 400 HDD",
#                             "docker_image": "quay.io/humancellatlas/secondary-analysis-cellranger:v1.0.0",
#                             "log_err": "gs://broad-dsde-mint-staging-cromwell-execution/caas-cromwell-executions/Adapter10xCount/5575252b-c6ba-47e4-9a6a-05ff828321bd/call-analysis/CellRanger.CellRanger/d0ee5b5e-c138-4eb9-b46a-d4e4626105a3/call-cellranger_count/stderr",
#                             "log_out": "gs://broad-dsde-mint-staging-cromwell-execution/caas-cromwell-executions/Adapter10xCount/5575252b-c6ba-47e4-9a6a-05ff828321bd/call-analysis/CellRanger.CellRanger/d0ee5b5e-c138-4eb9-b46a-d4e4626105a3/call-cellranger_count/stdout",
#                             "memory": "416 GB",
#                             "start_time": "2018-11-13T16:20:25.003Z",
#                             "stop_time": "2018-11-13T16:45:18.391Z",
#                             "task_name": "cellranger_count",
#                             "zone": "us-central1-b"
#                         }
#                     ],
#                     "timestamp_start_utc": "2018-11-13T16:20:22.963Z",
#                     "timestamp_stop_utc": "2018-11-13T16:45:20.323Z"
#                 }
#             ],
#             "analysis_protocol_json": [
#                 {
#                     "computational_method": "10x",
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/protocol/analysis/8.0.3/analysis_protocol",
#                     "protocol_core": {
#                         "protocol_id": "cellranger_v1.0.2"
#                     },
#                     "protocol_type": {
#                         "text": "analysis"
#                     },
#                     "provenance": {
#                         "document_id": "278e1ebf-55cc-4929-b00c-44d1e89f021e",
#                         "submission_date": "2018-11-13T16:49:56.965Z",
#                         "update_date": "2018-11-13T16:50:03.206Z"
#                     },
#                     "schema_type": "protocol"
#                 }
#             ],
#             "cell_suspension_json": [
#                 {
#                     "biomaterial_core": {
#                         "biomaterial_id": "Q4_DEMO-cellsus_SAMN02797092",
#                         "biosd_biomaterial": "SAMN00000000",
#                         "genotype": "DRB1 0401 protective allele",
#                         "insdc_biomaterial": "SRS0000000",
#                         "ncbi_taxon_id": [
#                             9606
#                         ]
#                     },
#                     "cell_morphology": {
#                         "cell_morphology": "adherent cells, form single layer colonies",
#                         "cell_size": "20-30",
#                         "cell_size_unit": {
#                             "ontology": "UO:0000018",
#                             "ontology_label": "nanometer",
#                             "text": "nm"
#                         },
#                         "cell_viability_method": "Fluorescein diacetate hydrolysis assay",
#                         "cell_viability_result": "pass",
#                         "percent_cell_viability": 85.3,
#                         "percent_necrosis": 10
#                     },
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/biomaterial/8.6.1/cell_suspension",
#                     "genus_species": [
#                         {
#                             "ontology": "NCBITaxon:9606",
#                             "ontology_label": "Homo sapiens",
#                             "text": "Homo sapiens"
#                         }
#                     ],
#                     "growth_conditions": {
#                         "drug_treatment": "100 ug/mL ampicillin",
#                         "feeder_layer_type": "feeder-dependent, mouse embryonic fibroblast cells",
#                         "growth_medium": "lysogeny broth (LB) medium",
#                         "mycoplasma_testing_results": "pass",
#                         "passage_number": 22
#                     },
#                     "provenance": {
#                         "document_id": "ca5de32f-636a-4862-a7f6-f755a5b8d85d",
#                         "submission_date": "2018-11-13T16:01:05.024Z",
#                         "update_date": "2018-11-13T16:01:09.912Z"
#                     },
#                     "schema_type": "biomaterial",
#                     "total_estimated_cells": 10000
#                 }
#             ],
#             "collection_protocol_json": [
#                 {
#                     "collection_method": {
#                         "ontology": "EFO:0009124",
#                         "ontology_label": "organ extraction",
#                         "text": "organ extraction"
#                     },
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/protocol/biomaterial_collection/8.2.6/collection_protocol",
#                     "protocol_core": {
#                         "document": "my_cool_protocol.pdf",
#                         "protocol_description": "A general description of the protocol.",
#                         "protocol_id": "collection_protocol1",
#                         "protocol_name": "A short, descriptive name for the protocol that need not be unique.",
#                         "protocols_io_doi": "10.17504/protocols.io.mgjc3un",
#                         "publication_doi": "10.1101/193219"
#                     },
#                     "protocol_reagents": [
#                         {
#                             "catalog_number": "20014279",
#                             "expiry_date": "2018-01-31",
#                             "kit_titer": "Titer: Specification is 3.0x10^7",
#                             "lot_number": "10001A",
#                             "manufacturer": "Illumina",
#                             "retail_name": "SureCell WTA 3' Library Prep Kit"
#                         }
#                     ],
#                     "provenance": {
#                         "document_id": "4c72135e-589c-4c98-8481-453fa30ea7fe",
#                         "submission_date": "2018-11-13T16:01:05.063Z",
#                         "update_date": "2018-11-13T16:01:09.399Z"
#                     },
#                     "schema_type": "protocol"
#                 }
#             ],
#             "dissociation_protocol_json": [
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/protocol/biomaterial_collection/5.0.3/dissociation_protocol",
#                     "dissociation_method": {
#                         "ontology": "EFO:0009108",
#                         "ontology_label": "fluorescence-activated cell sorting",
#                         "text": "fluorescence-activated cell sorting"
#                     },
#                     "protocol_core": {
#                         "protocol_description": "single cell",
#                         "protocol_id": "dissociation_1",
#                         "protocol_name": "a FACS method to separate cells"
#                     },
#                     "provenance": {
#                         "document_id": "2a1802e0-d73f-4bf5-940e-9285a36a696f",
#                         "submission_date": "2018-11-13T16:01:05.091Z",
#                         "update_date": "2018-11-13T16:01:09.406Z"
#                     },
#                     "schema_type": "protocol"
#                 }
#             ],
#             "donor_organism_json": [
#                 {
#                     "biomaterial_core": {
#                         "biomaterial_description": "A general description of a biomaterial",
#                         "biomaterial_id": "Q4_DEMO-donor_MGH30",
#                         "biomaterial_name": "Q4 DEMO donor MGH30",
#                         "biosd_biomaterial": "SAMN00000000",
#                         "genotype": "DRB1 0401 protective allele",
#                         "insdc_biomaterial": "SRS0000000",
#                         "ncbi_taxon_id": [
#                             9606
#                         ]
#                     },
#                     "death": {
#                         "cause_of_death": "motor vehicle accident",
#                         "cold_perfused": false,
#                         "days_on_ventilator": 4,
#                         "hardy_scale": 0,
#                         "organ_donation_death_type": "Donation after circulatory death (DCD)",
#                         "time_of_death": "2016-01-21T00:00:00Z"
#                     },
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/biomaterial/10.1.2/donor_organism",
#                     "diseases": [
#                         {
#                             "ontology": "MONDO:0001932",
#                             "ontology_label": "atrophic vulva",
#                             "text": "atrophic vulva"
#                         }
#                     ],
#                     "genus_species": [
#                         {
#                             "ontology": "NCBITaxon:9606",
#                             "ontology_label": "Homo sapiens",
#                             "text": "Homo sapiens"
#                         }
#                     ],
#                     "gestational_age": "5-7",
#                     "height": "160",
#                     "height_unit": {
#                         "ontology": "UO:0000015",
#                         "ontology_label": "centimeter",
#                         "text": "cm"
#                     },
#                     "human_specific": {
#                         "body_mass_index": 36.4,
#                         "ethnicity": [
#                             {
#                                 "ontology": "HANCESTRO:0005",
#                                 "ontology_label": "European",
#                                 "text": "European"
#                             }
#                         ]
#                     },
#                     "is_living": "no",
#                     "medical_history": {
#                         "alcohol_history": "3-6 units/day",
#                         "medication": "Naproxen 500mg/day, ",
#                         "nutritional_state": "normal",
#                         "smoking_history": "Smoker, 20/day for 25 years, stopped 2000"
#                     },
#                     "normothermic_regional_perfusion": "yes",
#                     "organism_age": "20",
#                     "organism_age_unit": {
#                         "ontology": "UO:0000036",
#                         "ontology_label": "year",
#                         "text": "year"
#                     },
#                     "provenance": {
#                         "document_id": "7767d009-93ee-4ef4-aad3-115e5a58c658",
#                         "submission_date": "2018-11-13T16:01:04.995Z",
#                         "update_date": "2018-11-13T16:01:09.783Z"
#                     },
#                     "schema_type": "biomaterial",
#                     "sex": "male",
#                     "weight": "60",
#                     "weight_unit": {
#                         "ontology": "UO:0000009",
#                         "ontology_label": "kilogram",
#                         "text": "kg"
#                     }
#                 }
#             ],
#             "enrichment_protocol_json": [
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/protocol/biomaterial_collection/2.2.5/enrichment_protocol",
#                     "enrichment_method": {
#                         "ontology": "EFO:0009108",
#                         "ontology_label": "fluorescence-activated cell sorting",
#                         "text": "fluorescence-activated cell sorting"
#                     },
#                     "markers": "CD4+ CD8-",
#                     "max_size_selected": 90,
#                     "min_size_selected": 70,
#                     "protocol_core": {
#                         "protocol_id": "enrichment1",
#                         "protocol_name": "an enrichment method to enrich for cells",
#                         "protocols_io_doi": "10.17504/protocols.io.mgjc3un",
#                         "publication_doi": "10.1101/193219"
#                     },
#                     "provenance": {
#                         "document_id": "183c22b4-db6b-4983-a1e2-3c6e5b5c46f1",
#                         "submission_date": "2018-11-13T16:01:05.098Z",
#                         "update_date": "2018-11-13T16:01:09.376Z"
#                     },
#                     "schema_type": "protocol"
#                 }
#             ],
#             "library_preparation_protocol_json": [
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/protocol/sequencing/4.3.3/library_preparation_protocol",
#                     "end_bias": "full length",
#                     "input_nucleic_acid_molecule": {
#                         "ontology": "OBI:0000869",
#                         "ontology_label": "polyA RNA",
#                         "text": "polyA RNA"
#                     },
#                     "library_construction_approach": {
#                         "ontology": "EFO:0009310",
#                         "ontology_label": "10X v2 sequencing",
#                         "text": "10x v2"
#                     },
#                     "library_preamplification_method": {
#                         "ontology": "EFO:0004182",
#                         "ontology_label": "Rapid Amplification of cDNA Ends",
#                         "text": "Rapid Amplification of cDNA Ends"
#                     },
#                     "primer": "poly-dT",
#                     "protocol_core": {
#                         "document": "my_cool_protocol.pdf",
#                         "protocol_id": "preparation1",
#                         "protocol_name": "Preparing RNA for sequencing by 10x",
#                         "protocols_io_doi": "10.17504/protocols.io.mgjc3un",
#                         "publication_doi": "10.1101/193219"
#                     },
#                     "provenance": {
#                         "document_id": "d4935e3e-3913-4c6e-b6ef-562ead6de048",
#                         "submission_date": "2018-11-13T16:01:05.084Z",
#                         "update_date": "2018-11-13T16:01:09.270Z"
#                     },
#                     "schema_type": "protocol",
#                     "strand": "unstranded",
#                     "umi_barcode": {
#                         "barcode_length": 16,
#                         "barcode_offset": 0,
#                         "barcode_read": "Read 1"
#                     }
#                 }
#             ],
#             "links_json": [
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/system/1.1.3/links",
#                     "links": [
#                         {
#                             "input_type": "file",
#                             "inputs": [
#                                 "955d3faa-4a23-4ec5-8859-7863be29913f",
#                                 "5ffbdc7b-ed72-4c4b-a007-efd84680d88c",
#                                 "be567b17-1c87-451b-acc6-5f87f163bcac"
#                             ],
#                             "output_type": "file",
#                             "outputs": [
#                                 "56307381-7bf5-472f-9d90-d1ee73675932",
#                                 "e07c6f55-509f-4e07-b6ea-88b03ac4dbce",
#                                 "d8c11c8b-a8a2-425d-b839-c7be1a29fc51",
#                                 "93d5756e-5d7f-4521-9b8e-0347f1f1984d",
#                                 "ed7ae77f-3931-4a02-aef0-febda5ad4400",
#                                 "12ce9831-e48c-448e-8a4c-0923c020d31e",
#                                 "40f703ec-a6c9-48c3-ba46-c348f2b4476d",
#                                 "3edf5182-694a-4090-bf02-51ac23b3c9ee",
#                                 "b90c2ea5-6a20-41b3-921e-b7e17a25a54b",
#                                 "5024ce72-e49a-4cc6-a141-9f30f0e19680",
#                                 "81104335-7f3a-4a44-a0dd-8f23810dd073",
#                                 "f5e19e2c-19c9-4728-b445-4bf34f6f7fc9",
#                                 "0991f785-3ba6-4599-adb4-d984a5e8bcc1"
#                             ],
#                             "process": "98ee9a53-89c3-4e01-b2d2-d9925e8aee53",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "278e1ebf-55cc-4929-b00c-44d1e89f021e",
#                                     "protocol_type": "analysis_protocol"
#                                 }
#                             ]
#                         },
#                         {
#                             "input_type": "biomaterial",
#                             "inputs": [
#                                 "ca5de32f-636a-4862-a7f6-f755a5b8d85d"
#                             ],
#                             "output_type": "file",
#                             "outputs": [
#                                 "955d3faa-4a23-4ec5-8859-7863be29913f",
#                                 "5ffbdc7b-ed72-4c4b-a007-efd84680d88c",
#                                 "be567b17-1c87-451b-acc6-5f87f163bcac"
#                             ],
#                             "process": "06e94fcf-b912-451b-b91f-7ac3f88c8b3c",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "d4935e3e-3913-4c6e-b6ef-562ead6de048",
#                                     "protocol_type": "library_preparation_protocol"
#                                 },
#                                 {
#                                     "protocol_id": "1f5edb50-473d-48db-a50e-4dc3b43463e3",
#                                     "protocol_type": "sequencing_protocol"
#                                 }
#                             ]
#                         },
#                         {
#                             "input_type": "biomaterial",
#                             "inputs": [
#                                 "637d6d21-f1e7-465e-a156-8fd3476ea6c1"
#                             ],
#                             "output_type": "biomaterial",
#                             "outputs": [
#                                 "ca5de32f-636a-4862-a7f6-f755a5b8d85d"
#                             ],
#                             "process": "bc4da5de-09eb-4a2d-afd6-647fc5675f35",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "2a1802e0-d73f-4bf5-940e-9285a36a696f",
#                                     "protocol_type": "dissociation_protocol"
#                                 },
#                                 {
#                                     "protocol_id": "183c22b4-db6b-4983-a1e2-3c6e5b5c46f1",
#                                     "protocol_type": "enrichment_protocol"
#                                 }
#                             ]
#                         },
#                         {
#                             "input_type": "biomaterial",
#                             "inputs": [
#                                 "7767d009-93ee-4ef4-aad3-115e5a58c658"
#                             ],
#                             "output_type": "biomaterial",
#                             "outputs": [
#                                 "637d6d21-f1e7-465e-a156-8fd3476ea6c1"
#                             ],
#                             "process": "1deee136-46c7-486c-a739-36d09591e057",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "4c72135e-589c-4c98-8481-453fa30ea7fe",
#                                     "protocol_type": "collection_protocol"
#                                 }
#                             ]
#                         },
#                         {
#                             "input_type": "biomaterial",
#                             "inputs": [
#                                 "ca5de32f-636a-4862-a7f6-f755a5b8d85d"
#                             ],
#                             "output_type": "file",
#                             "outputs": [
#                                 "955d3faa-4a23-4ec5-8859-7863be29913f",
#                                 "5ffbdc7b-ed72-4c4b-a007-efd84680d88c",
#                                 "be567b17-1c87-451b-acc6-5f87f163bcac"
#                             ],
#                             "process": "06e94fcf-b912-451b-b91f-7ac3f88c8b3c",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "d4935e3e-3913-4c6e-b6ef-562ead6de048",
#                                     "protocol_type": "library_preparation_protocol"
#                                 },
#                                 {
#                                     "protocol_id": "1f5edb50-473d-48db-a50e-4dc3b43463e3",
#                                     "protocol_type": "sequencing_protocol"
#                                 }
#                             ]
#                         },
#                         {
#                             "input_type": "biomaterial",
#                             "inputs": [
#                                 "637d6d21-f1e7-465e-a156-8fd3476ea6c1"
#                             ],
#                             "output_type": "biomaterial",
#                             "outputs": [
#                                 "ca5de32f-636a-4862-a7f6-f755a5b8d85d"
#                             ],
#                             "process": "bc4da5de-09eb-4a2d-afd6-647fc5675f35",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "2a1802e0-d73f-4bf5-940e-9285a36a696f",
#                                     "protocol_type": "dissociation_protocol"
#                                 },
#                                 {
#                                     "protocol_id": "183c22b4-db6b-4983-a1e2-3c6e5b5c46f1",
#                                     "protocol_type": "enrichment_protocol"
#                                 }
#                             ]
#                         },
#                         {
#                             "input_type": "biomaterial",
#                             "inputs": [
#                                 "7767d009-93ee-4ef4-aad3-115e5a58c658"
#                             ],
#                             "output_type": "biomaterial",
#                             "outputs": [
#                                 "637d6d21-f1e7-465e-a156-8fd3476ea6c1"
#                             ],
#                             "process": "1deee136-46c7-486c-a739-36d09591e057",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "4c72135e-589c-4c98-8481-453fa30ea7fe",
#                                     "protocol_type": "collection_protocol"
#                                 }
#                             ]
#                         },
#                         {
#                             "input_type": "biomaterial",
#                             "inputs": [
#                                 "ca5de32f-636a-4862-a7f6-f755a5b8d85d"
#                             ],
#                             "output_type": "file",
#                             "outputs": [
#                                 "955d3faa-4a23-4ec5-8859-7863be29913f",
#                                 "5ffbdc7b-ed72-4c4b-a007-efd84680d88c",
#                                 "be567b17-1c87-451b-acc6-5f87f163bcac"
#                             ],
#                             "process": "06e94fcf-b912-451b-b91f-7ac3f88c8b3c",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "d4935e3e-3913-4c6e-b6ef-562ead6de048",
#                                     "protocol_type": "library_preparation_protocol"
#                                 },
#                                 {
#                                     "protocol_id": "1f5edb50-473d-48db-a50e-4dc3b43463e3",
#                                     "protocol_type": "sequencing_protocol"
#                                 }
#                             ]
#                         },
#                         {
#                             "input_type": "biomaterial",
#                             "inputs": [
#                                 "637d6d21-f1e7-465e-a156-8fd3476ea6c1"
#                             ],
#                             "output_type": "biomaterial",
#                             "outputs": [
#                                 "ca5de32f-636a-4862-a7f6-f755a5b8d85d"
#                             ],
#                             "process": "bc4da5de-09eb-4a2d-afd6-647fc5675f35",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "2a1802e0-d73f-4bf5-940e-9285a36a696f",
#                                     "protocol_type": "dissociation_protocol"
#                                 },
#                                 {
#                                     "protocol_id": "183c22b4-db6b-4983-a1e2-3c6e5b5c46f1",
#                                     "protocol_type": "enrichment_protocol"
#                                 }
#                             ]
#                         },
#                         {
#                             "input_type": "biomaterial",
#                             "inputs": [
#                                 "7767d009-93ee-4ef4-aad3-115e5a58c658"
#                             ],
#                             "output_type": "biomaterial",
#                             "outputs": [
#                                 "637d6d21-f1e7-465e-a156-8fd3476ea6c1"
#                             ],
#                             "process": "1deee136-46c7-486c-a739-36d09591e057",
#                             "protocols": [
#                                 {
#                                     "protocol_id": "4c72135e-589c-4c98-8481-453fa30ea7fe",
#                                     "protocol_type": "collection_protocol"
#                                 }
#                             ]
#                         }
#                     ],
#                     "schema_type": "link_bundle",
#                     "schema_version": "1.1.3"
#                 }
#             ],
#             "process_json": [
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/process/6.0.2/process",
#                     "process_core": {
#                         "process_id": "bundle1"
#                     },
#                     "provenance": {
#                         "document_id": "06e94fcf-b912-451b-b91f-7ac3f88c8b3c",
#                         "submission_date": "2018-11-13T16:01:05.123Z",
#                         "update_date": "2018-11-13T16:01:09.775Z"
#                     },
#                     "schema_type": "process"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/process/6.0.2/process",
#                     "process_core": {
#                         "process_id": "process_id_2"
#                     },
#                     "provenance": {
#                         "document_id": "bc4da5de-09eb-4a2d-afd6-647fc5675f35",
#                         "submission_date": "2018-11-13T16:01:05.114Z",
#                         "update_date": "2018-11-13T16:01:09.679Z"
#                     },
#                     "schema_type": "process"
#                 },
#                 {
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/process/6.0.2/process",
#                     "process_core": {
#                         "process_id": "process_id_1"
#                     },
#                     "provenance": {
#                         "document_id": "1deee136-46c7-486c-a739-36d09591e057",
#                         "submission_date": "2018-11-13T16:01:05.106Z",
#                         "update_date": "2018-11-13T16:01:09.722Z"
#                     },
#                     "schema_type": "process"
#                 }
#             ],
#             "project_json": [
#                 {
#                     "array_express_investigation": "E-AAAA-00",
#                     "contributors": [
#                         {
#                             "address": "0000 Main Street, Nowheretown, MA, 12091",
#                             "contact_name": "John,D,Doe. ",
#                             "corresponding_contributor": false,
#                             "country": "USA",
#                             "email": "dummy@email.com",
#                             "institution": "EMBL-EBI",
#                             "laboratory": "Department of Biology",
#                             "orcid_id": "0000-1111-2222-3333",
#                             "phone": "(+1) 234-555-6789",
#                             "project_role": "principal investigator"
#                         }
#                     ],
#                     "describedBy": "http://schema.staging.data.humancellatlas.org/type/project/9.0.3/project",
#                     "funders": [
#                         {
#                             "funder_name": "Biotechnology and Biological Sciences Research Council (BBSRC)",
#                             "grant_id": "BB/P0000001/1",
#                             "grant_title": "A title of a grant proposal."
#                         }
#                     ],
#                     "geo_series": "GSE00000",
#                     "insdc_project": "SRP000000",
#                     "insdc_study": "PRJNA000000",
#                     "project_core": {
# ...
#                     "crc32c": "f2b81ade",
#                     "indexed": true,
#                     "name": "dissociation_protocol_0.json",
#                     "s3-etag": "8c2667922ff8137497dbc10ad137d4eb",
#                     "sha1": "b3bceb84227b26900f08f1cb1b9e3b4410b6711c",
#                     "sha256": "34ae9e26e63216c76d243b86e3fa2216b8618c78cf973eb9c2e9a4b92fe0b4f2",
#                     "size": 728,
#                     "uuid": "2a1802e0-d73f-4bf5-940e-9285a36a696f",
#                     "version": "2018-11-13T160109.406000Z"
#                 },
#                 {
#                     "content-type": "application/json; dcp-type=\"metadata/protocol\"",
#                     "crc32c": "b3f999bd",
#                     "indexed": true,
#                     "name": "enrichment_protocol_0.json",
#                     "s3-etag": "88731c0f1ab4e9cfc2fb1c41d36bb8c4",
#                     "sha1": "317be2fd7597f5717885b21fae64d29337e468d1",
#                     "sha256": "d613c6e56637cdc3f8c121aec78adb472358f33713c880c702b491ac6bcb69df",
#                     "size": 875,
#                     "uuid": "183c22b4-db6b-4983-a1e2-3c6e5b5c46f1",
#                     "version": "2018-11-13T160109.376000Z"
#                 },
#                 {
#                     "content-type": "application/json; dcp-type=\"metadata/protocol\"",
#                     "crc32c": "faf931ef",
#                     "indexed": true,
#                     "name": "collection_protocol_0.json",
#                     "s3-etag": "6f51a735873eac093cfd30d1bff62f28",
#                     "sha1": "935b650db2e18f37435aca49d0949c24dd0dedc9",
#                     "sha256": "2886af846d70a0dc9dfb2e60156484aa067ccbec783bdf08f8322dd13a4f08ad",
#                     "size": 1241,
#                     "uuid": "4c72135e-589c-4c98-8481-453fa30ea7fe",
#                     "version": "2018-11-13T160109.399000Z"
#                 },
#                 {
#                     "content-type": "application/json; dcp-type=\"metadata/process\"",
#                     "crc32c": "6932b74d",
#                     "indexed": true,
#                     "name": "analysis_process_0.json",
#                     "s3-etag": "2d2db737913bcaac6e12ef0a16521314",
#                     "sha1": "5fccebbdce6635374f1a9e1b456b2d065436f265",
#                     "sha256": "294e71ac51e8ba6e3561d1fc052fa4465fd67f0caf266ad5659597aed06b546e",
#                     "size": 6616,
#                     "uuid": "98ee9a53-89c3-4e01-b2d2-d9925e8aee53",
#                     "version": "2018-11-13T165003.286000Z"
#                 },
#                 {
#                     "content-type": "application/json; dcp-type=\"metadata/process\"",
#                     "crc32c": "047d5de9",
#                     "indexed": true,
#                     "name": "process_0.json",
#                     "s3-etag": "c91971e3adb143880363ed6136b93f5c",
#                     "sha1": "aeb25b700ca34e971332afc895b75a3adb79761c",
#                     "sha256": "1c32c76f55b546e44615f47f0cbb0d35645d10f070938251224b4356bf7c1f50",
#                     "size": 383,
#                     "uuid": "06e94fcf-b912-451b-b91f-7ac3f88c8b3c",
#                     "version": "2018-11-13T160109.775000Z"
#                 },
#                 {
#                     "content-type": "application/json; dcp-type=\"metadata/process\"",
#                     "crc32c": "3dd443b5",
#                     "indexed": true,
#                     "name": "process_1.json",
#                     "s3-etag": "92d98eb78adcd0c0b0c55d63073f4a75",
#                     "sha1": "a5fdaf9819920f74ef3fedb54195d13bfdc993f8",
#                     "sha256": "b0bc50a2ba78f128a62046d2f7419b88c8d9c898b3ee8ad57a88e4c742c70a6a",
#                     "size": 388,
#                     "uuid": "bc4da5de-09eb-4a2d-afd6-647fc5675f35",
#                     "version": "2018-11-13T160109.679000Z"
#                 },
#                 {
#                     "content-type": "application/json; dcp-type=\"metadata/process\"",
#                     "crc32c": "cb492d4d",
#                     "indexed": true,
#                     "name": "process_2.json",
#                     "s3-etag": "792e4905f59d8ef05d5f574ddbc12709",
#                     "sha1": "0bb197e05050be058b1ba83306531852219e98db",
#                     "sha256": "12e505274507a6073eb2f024b42c957e7dcc0fdc9e1da6ebe327d6d1651670c9",
#                     "size": 388,
#                     "uuid": "1deee136-46c7-486c-a739-36d09591e057",
#                     "version": "2018-11-13T160109.722000Z"
#                 },
#                 {
#                     "content-type": "application/json; dcp-type=\"metadata/links\"",
#                     "crc32c": "2233be3c",
#                     "indexed": true,
#                     "name": "links.json",
#                     "s3-etag": "034031d9b817d364f13a3a90eba01971",
#                     "sha1": "55ac44046c097a49a2374ca3b7da7fc7ac2b7b8d",
#                     "sha256": "670358dd30314c0d117da61832c493883fc63f6b4df9ab19d515cd0285e4b739",
#                     "size": 7987,
#                     "uuid": "9314fbf4-be6e-4b51-9e3e-5a780b473fb1",
#                     "version": "2018-11-13T165538.715657Z"
#                 },
#                 {
#                     "content-type": "text/tab-separated-values; dcp-type=data",
#                     "crc32c": "ce4f092f",
#                     "indexed": false,
#                     "name": "barcodes.tsv",
#                     "s3-etag": "2efbd14bdb0d08278291f3bbb6e06d17",
#                     "sha1": "df7a8ee1be9c56990d0a8b65b1b12a3f7dac08cb",
#                     "sha256": "c659bc3d4320afd0024b1dcc0404a55f45a3e645f6c891fddd1d5f434a9c5cfb",
#                     "size": 81263,
#                     "uuid": "3db9b3bd-0fde-430a-81e2-557febab60c2",
#                     "version": "2018-11-13T165538.990410Z"
#                 },
#                 {
#                     "content-type": "text/tab-separated-values; dcp-type=data",
#                     "crc32c": "7571fac9",
#                     "indexed": false,
#                     "name": "genes.tsv",
#                     "s3-etag": "fa0cca9a56bcfc1ef745fdb696492040",
#                     "sha1": "dd08d5183735a7c31e823a1402c422cf2735fba8",
#                     "sha256": "4ce78cc6539d6bff305c602c6c341cf2a3aa167ec804b25c137ef2547103b250",
#                     "size": 892197,
#                     "uuid": "7ccb6e30-a1b4-496a-ac34-97438955d3d4",
#                     "version": "2018-11-13T165539.240948Z"
#                 },
#                 {
#                     "content-type": "application/octet-stream; dcp-type=data",
#                     "crc32c": "62f19998",
#                     "indexed": false,
#                     "name": "matrix.mtx",
#                     "s3-etag": "3c8eed7af9be50e18a970cdbf3f84b0b",
#                     "sha1": "3072e247a56754421298667afcead235749b319a",
#                     "sha256": "a8417f0e710ba619dc80d24b0579d4ef936a54917cc76ade38ad8dcbb69ebf6c",
#                     "size": 5122376,
#                     "uuid": "58617006-db67-45df-8623-97343b59cd77",
#                     "version": "2018-11-13T165539.521901Z"
#                 },
#                 {
#                     "content-type": "application/octet-stream; dcp-type=data",
#                     "crc32c": "56a9107f",
#                     "indexed": false,
#                     "name": "filtered_gene_bc_matrices_h5.h5",
#                     "s3-etag": "2212be94484f80c0e46dd581ec085baa",
#                     "sha1": "c0e04ea5147aad29d6735d235f5d67ca7ca26ce8",
#                     "sha256": "2c5699023f0e3553264e03f1c76dfd33b2b5bf7e221e8ecf1c2282b24e4e020a",
#                     "size": 1128519,
#                     "uuid": "095afe5a-8cdd-4246-8fe7-8483187ff1d6",
#                     "version": "2018-11-13T165539.760211Z"
#                 },
#                 {
#                     "content-type": "text/csv; dcp-type=data",
#                     "crc32c": "d2b3ada1",
#                     "indexed": false,
#                     "name": "metrics_summary.csv",
#                     "s3-etag": "f304bc0aabc1108abf0c12c3c7b7c861",
#                     "sha1": "942882e956b0a4237ea7dd77751472bc40ce32c7",
#                     "sha256": "17073688d5a9ab027b4830358b5121c55e10b4406a6bbb65d457bd7df56fd5c5",
#                     "size": 668,
#                     "uuid": "1fbe23f9-f51f-45e2-b65c-a0e2923398d8",
#                     "version": "2018-11-13T165540.072717Z"
#                 },
#                 {
#                     "content-type": "application/octet-stream; dcp-type=data",
#                     "crc32c": "411dac00",
#                     "indexed": false,
#                     "name": "molecule_info.h5",
#                     "s3-etag": "831a9dc4cca2bf473d6e2d72262fab9a",
#                     "sha1": "104c77e3e9dc6c30b66356d12106b2e9d155352b",
#                     "sha256": "4ec0d5b66494e4f6a669bc25f06b30cfbebe02f3fdf176c9d22f0c446ca760eb",
#                     "size": 4712924,
#                     "uuid": "9b5f23b3-23ce-481b-a9fd-832ba2bd889c",
#                     "version": "2018-11-13T165540.347903Z"
#                 },
#                 {
#                     "content-type": "application/gzip; dcp-type=data",
#                     "crc32c": "4f81a1ea",
#                     "indexed": false,
#                     "name": "possorted_genome_bam.bam",
#                     "s3-etag": "58269a35f9bf5a2fe787fa0009919238-2",
#                     "sha1": "f3b981d55d87374146e250fb80dafa79c896f0bd",
#                     "sha256": "7d193c0aa0cf0f612bd92f63567da215a71e6c1c412c8de6035904c861fcf20c",
#                     "size": 108954397,
#                     "uuid": "fda87f01-72df-4fb9-9216-bdba35962497",
#                     "version": "2018-11-13T165540.711583Z"
#                 },
#                 {
#                     "content-type": "application/octet-stream; dcp-type=data",
#                     "crc32c": "6c23adaf",
#                     "indexed": false,
#                     "name": "possorted_genome_bam.bam.bai",
#                     "s3-etag": "c27141aa04751493226564dac7c654ef",
#                     "sha1": "88b3594a3e32ac5a2e8a7943717d7e9f09003ff3",
#                     "sha256": "40274c2c2adcbd1148f442046c8901de58650104c0a1b827e39a04d398d4279d",
#                     "size": 2512152,
#                     "uuid": "d73e0cf0-c410-4264-aeb2-9ad0de59e68c",
#                     "version": "2018-11-13T165540.993515Z"
#                 },
#                 {
#                     "content-type": "application/octet-stream; dcp-type=data",
#                     "crc32c": "1993bad2",
#                     "indexed": false,
#                     "name": "raw_gene_bc_matrices_h5.h5",
#                     "s3-etag": "661c60a1b217c07c0c34ae77340046e5",
#                     "sha1": "a4905e776031c99f2cee3654c100f5d99e6e39ce",
#                     "sha256": "be3f4ab8bb12d89eee72a4910d51ba5c26d92bfce75b73ce922d72029991359b",
#                     "size": 2557925,
#                     "uuid": "0024e265-6a79-4e46-a795-e25ef9dd6f50",
#                     "version": "2018-11-13T165541.350800Z"
#                 },
#                 {
#                     "content-type": "text/html; dcp-type=data",
#                     "crc32c": "4ad927c2",
#                     "indexed": false,
#                     "name": "web_summary.html",
#                     "s3-etag": "3f9c4537186ce7d3890c953c19e9c33a",
#                     "sha1": "e4ced767bf116c5bd8e880f58f6dd1488b0c5f51",
#                     "sha256": "9820e99711dbc1ff5505517c18b6d5507006216d4514c64b62c29d4041dbb8bf",
#                     "size": 2646661,
#                     "uuid": "58dc1b0e-f4c1-4b42-8635-ebabc38fc892",
#                     "version": "2018-11-13T165541.671932Z"
#                 },
#                 {
#                     "content-type": "text/tab-separated-values; dcp-type=data",
#                     "crc32c": "7c54ea3d",
#                     "indexed": false,
#                     "name": "raw_barcodes.tsv",
#                     "s3-etag": "f010059d7160aac2dad1805e1496bf71",
#                     "sha1": "131a9a81a9666418c503e65828a9a0ac460530ca",
#                     "sha256": "e28353c088bf3b4d660220377a5f5fcc64839fb9e307cea47afe4e23fce2edc2",
#                     "size": 14008320,
#                     "uuid": "e33ac23e-123f-4784-8b42-d1a338c767e2",
#                     "version": "2018-11-13T165541.981251Z"
#                 },
#                 {
#                     "content-type": "text/tab-separated-values; dcp-type=data",
#                     "crc32c": "7571fac9",
#                     "indexed": false,
#                     "name": "raw_genes.tsv",
#                     "s3-etag": "fa0cca9a56bcfc1ef745fdb696492040",
#                     "sha1": "dd08d5183735a7c31e823a1402c422cf2735fba8",
#                     "sha256": "4ce78cc6539d6bff305c602c6c341cf2a3aa167ec804b25c137ef2547103b250",
#                     "size": 892197,
#                     "uuid": "8217736d-700c-485a-b5ae-37e84eae9d00",
#                     "version": "2018-11-13T165542.226077Z"
#                 },
#                 {
#                     "content-type": "application/octet-stream; dcp-type=data",
#                     "crc32c": "275878e7",
#                     "indexed": false,
#                     "name": "raw_matrix.mtx",
#                     "s3-etag": "f9ec11daeddc0d41c024e45a86377ec7",
#                     "sha1": "34b9cdb38e3fce8713a1296053f29cde4573ba18",
#                     "sha256": "1513efcd106b5590a5796ed26704d5d7a966ff7489fe4b14021e1409573ee512",
#                     "size": 6636338,
#                     "uuid": "1bdf5eb4-93f0-4853-b1f9-ca15f36ef92f",
#                     "version": "2018-11-13T165542.480365Z"
#                 },
#                 {
#                     "content-type": "application/gzip; dcp-type=data",
#                     "crc32c": "0dd4606e",
#                     "indexed": false,
#                     "name": "pbmc4k_S1_L001_R1_001.fastq.gz",
#                     "s3-etag": "f0f87c94d72e9be7df9846282c570115",
#                     "sha1": "9dd599a809f883ae3ff7a016b8609f067875e2d4",
#                     "sha256": "809bae8b5525bf7c3185d732c19bf6f6a7f1447585d3446faefcc549e2ac553f",
#                     "size": 20753596,
#                     "uuid": "4b3162b6-0a18-4120-a855-c209e0c06bee",
#                     "version": "2018-11-13T161440.035923Z"
#                 },
#                 {
#                     "content-type": "application/gzip; dcp-type=data",
#                     "crc32c": "3106c234",
#                     "indexed": false,
#                     "name": "pbmc4k_S1_L001_R2_001.fastq.gz",
#                     "s3-etag": "dc473e49e6e755ffa7c1da55468e4de5",
#                     "sha1": "b03070f93f0ca1646c9daa5643b44e5735d3fbc3",
#                     "sha256": "a797b7c7becae48744a9bcf2712fb82ff368983ebb4e33fa362381fe36f6f4ff",
#                     "size": 62275373,
#                     "uuid": "e6c61986-d381-4677-9e33-340cebd18564",
#                     "version": "2018-11-13T161440.229779Z"
#                 },
#                 {
#                     "content-type": "application/gzip; dcp-type=data",
#                     "crc32c": "edc27e7c",
#                     "indexed": false,
#                     "name": "pbmc4k_S1_L001_I1_001.fastq.gz",
#                     "s3-etag": "b54f3d4f74c40c8ae514fffc5431bf23",
#                     "sha1": "e65037fbcaccb52f824bbaedff9aa6df2f93c777",
#                     "sha256": "44e51cbc4d6ec81d74f5b6dd26f77b4a2432689b9beb38dc018fb7c58d9d6ade",
#                     "size": 6954894,
#                     "uuid": "68f52f7a-1496-47bd-bbfb-d76d3aad6cba",
#                     "version": "2018-11-13T161440.398668Z"
#                 }
#             ],
#             "format": "0.0.1",
#             "version": "2018-11-13T165615.841022Z"
#         },
#         "shape_descriptor": "v.analysis_file.5.analysis_process.8.analysis_protocol.8.cell_suspension.8.collection_protocol.8.dissociation_protocol.5.donor_organism.10.enrichment_protocol.2.library_preparation_protocol.4.links.1.process.6.project.9.sequence_file.6.sequencing_protocol.9.specimen_from_organism.6",
#         "state": "new",
#         "uuid": "02be9959-4616-4f24-ad30-c5f0611694e6"
#     },
#     "search_score": null
# }

# %% [markdown]
# There we go! It looks kind of messy, but now that we know where the `total_estimated_cells` and `organ` fields lie, we can finish our ElasticSearch query.

# %%
query = {
    "query" : {
        "bool" : {
            "must" : [
                {
                    "match" : {
                        "files.specimen_from_organism_json.organ.text" : organ_type
                    }
                },
                {
                    "exists" : { "field" : "files.cell_suspension_json.total_estimated_cells" }
                }
            ]
        }
    }
}

# %% [markdown]
# Now, let's see if this returns any results. We don't need `raw` `output_format` here since all we want from our search is the total number of hits.

# %%
client.post_search(es_query=query, replica='aws')['total_hits']
# Out:
# 34179

# %% [markdown]
# Great, we got something. It looks like we have plenty of bundles containing some number of brain cells. Now we just need to add them up.

# %%
# Iterate through all search results containing the chosen cell type

count = 0
for bundle in client.post_search.iterate(es_query=query, replica='aws', output_format='raw'):
    count += bundle['metadata']['files']['cell_suspension_json'][0]['total_estimated_cells']
print('{} cell count: {}'.format(organ_type, count))
# Out:
# brain cell count: 141770004

# %% [markdown]
# Alright, it looks like we're done here. Our program returned ~140 million cells total out of the bundles we searched.
